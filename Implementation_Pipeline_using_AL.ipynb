# %% [markdown]
# <a href="https://colab.research.google.com/github/muajnstu/Bank-Marketing-using-rough-set-approach/blob/main/Implementation_Pipeline_using_AL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Run this only once in your environment (e.g., terminal or notebook cell)
# !pip install -q imbalanced-learn catboost xgboost lightgbm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 7.5 MB/s eta 0:00:00

# %%
import os
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,
    confusion_matrix, matthews_corrcoef, classification_report, roc_curve, auc
)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, RidgeClassifier, Lasso, ElasticNet, Perceptron
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    StackingClassifier, VotingClassifier,
    RandomForestClassifier, GradientBoostingClassifier,
    ExtraTreesClassifier, BaggingClassifier, AdaBoostClassifier
)
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.gaussian_process import GaussianProcessClassifier

import warnings
warnings.filterwarnings("ignore", message="'force_all_finite' was renamed to 'ensure_all_finite'")
warnings.filterwarnings("ignore", message="Parameters: { \"use_label_encoder\" } are not used.")
warnings.filterwarnings("ignore", message=".*does not have valid feature names.*")

# %%
data = pd.read_csv('https://raw.githubusercontent.com/muajnstu/Bank-Marketing-using-rough-set-approach/refs/heads/main/MicroClustered_bank_data.csv')


# Separate features and target
X = data.drop('Personal_Loan', axis=1)
y = data['Personal_Loan']

# %%
# --- Base estimators
base_estimators = [
    ("lr",  LogisticRegression(max_iter=1000)),
    ("rf",  RandomForestClassifier(random_state=42)),
    ("gb",  GradientBoostingClassifier(random_state=42)),
    ("xgb", XGBClassifier(eval_metric='logloss', random_state=42, use_label_encoder=False)),
    ("lgbm",LGBMClassifier(verbosity=-1)),
    ("svm", SVC(probability=True)),
    ("et",  ExtraTreesClassifier(random_state=42)),
    ("knn", KNeighborsClassifier()),
]

classifiers = {
    "Logistic Regression":   LogisticRegression(max_iter=1000),
    "SVM":                   SVC(),
    "Naive Bayes":           GaussianNB(),
    "K-Nearest Neighbors":   KNeighborsClassifier(),
    "Decision Tree":         DecisionTreeClassifier(),
    "Random Forest":         RandomForestClassifier(random_state=42),
    "Gradient Boosting":     GradientBoostingClassifier(random_state=42),
    "XGBoost":               XGBClassifier(eval_metric='logloss', random_state=42, enable_categorical=True),
    "LightGBM":              LGBMClassifier(verbosity=-1),
    "CatBoost":              CatBoostClassifier(verbose=0, random_state=42),
    "AdaBoost":              AdaBoostClassifier(random_state=42),
    "Extra Trees":           ExtraTreesClassifier(random_state=42),
    "Ridge Classifier":      RidgeClassifier(),
    "Perceptron":            Perceptron(),
    "Bagging Classifier":    BaggingClassifier(random_state=42),
    "GaussianNB":            GaussianNB(),

    # ── Stacking
    "Stacking": StackingClassifier(
        estimators=base_estimators,
        final_estimator=LogisticRegression(max_iter=1000),
        cv=5,
        passthrough=False,
        n_jobs=-1
    ),

    # ── Hard Voting
    "Hard Voting": VotingClassifier(
        estimators=base_estimators,
        voting='hard',
        n_jobs=-1
    ),

    # ── Soft Voting
    "Soft Voting": VotingClassifier(
        estimators=base_estimators,
        voting='soft',
        n_jobs=-1
    ),

    # ── Weighted Soft Voting
    "Weighted Voting": VotingClassifier(
        estimators=base_estimators,
        voting='soft',
        weights=[
            3,   # lr   –
            4,   # rf
            4,   # gb
            5,   # xgb
            5,   # lgbm
            2,   # svm
            3,   # et
            2,   # knn
        ],
        n_jobs=-1
    ),

    # ── Adding / Averaging (soft alias)
    "Adding (Avg Probabilities)": VotingClassifier(
        estimators=base_estimators,
        voting='soft',
        weights=[1, 1, 1, 1, 1, 1, 1, 1],
        n_jobs=-1
    ),
}

# %%
def remove_instance(X, y, idx):
    X_new = np.delete(X, idx, axis=0)
    y_new = np.delete(y, idx, axis=0)
    return X_new, y_new

def g_mean(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    recalls = []
    for i in range(cm.shape[0]):
        tp = cm[i, i]
        fn = np.sum(cm[i, :]) - tp
        recall_i = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        recalls.append(recall_i)

    valid_recalls = [r for r in recalls if r > 0]
    if not valid_recalls:
        return 0.0

    product = 1.0
    for r in valid_recalls:
        product *= r
    return product ** (1.0 / len(valid_recalls))

# %%
def run_active_learning(X_data, y_data, clf,
                        test_size=0.20,
                        initial_pool=500,
                        n_iterations=10,
                        random_state=42):
    """
    Runs the active learning loop for a single classifier + dataset.
    Returns a list of dicts (one per iteration) with raw metric values.
    """
    y_data        = np.array(y_data, dtype=int)
    unique_classes = np.unique(y_data)

    X_train_full, X_test, y_train_full, y_test = train_test_split(
        X_data, y_data,
        test_size=test_size,
        random_state=random_state,
        stratify=y_data
    )

    if hasattr(X_test, 'values'):
        X_test = X_test.values

    np.random.seed(random_state)

    # ── Seed: one sample per class to guarantee all classes from iteration 1
    seed_idx = np.array([
        np.where(y_train_full == c)[0][0]
        for c in unique_classes
    ])

    # ── Fill remaining slots up to initial pool size
    remaining_pool = np.array([i for i in range(len(X_train_full))
                                if i not in seed_idx])
    n_extra    = max(0, initial_pool - len(seed_idx))
    extra_idx  = np.random.choice(remaining_pool, size=n_extra, replace=False)
    labeled_idx = np.concatenate([seed_idx, extra_idx])
    unlabeled_idx = np.array([i for i in range(len(X_train_full))
                               if i not in labeled_idx])

    # ── Build labeled / unlabeled arrays
    if hasattr(X_train_full, 'iloc'):
        X_labeled   = X_train_full.iloc[labeled_idx].values
        X_unlabeled = X_train_full.iloc[unlabeled_idx].values
    else:
        X_labeled   = X_train_full[labeled_idx]
        X_unlabeled = X_train_full[unlabeled_idx]

    y_labeled   = y_train_full[labeled_idx]
    y_unlabeled = y_train_full[unlabeled_idx]

    history = []

    # ── Active Learning Loop
    for i in range(n_iterations):
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")

            clf.fit(X_labeled, y_labeled)

            # Uncertainty sampling
            if hasattr(clf, "predict_proba"):
                probs       = clf.predict_proba(X_unlabeled)
                uncertainty = 1 - np.max(probs, axis=1)
            else:
                uncertainty = np.random.rand(len(X_unlabeled))

            # Query most uncertain sample → move to labeled
            query_idx   = np.argmax(uncertainty)
            X_labeled   = np.vstack([X_labeled, X_unlabeled[query_idx].reshape(1, -1)])
            y_labeled   = np.append(y_labeled, y_unlabeled[query_idx])
            X_unlabeled, y_unlabeled = remove_instance(X_unlabeled, y_unlabeled, query_idx)

            history.append({
                'iteration'      : i + 1,
                'labeled_samples': len(X_labeled),
                'y_test'         : y_test,
                'y_pred'         : clf.predict(X_test),
                'y_score'        : clf.predict_proba(X_test)
                                   if hasattr(clf, 'predict_proba') else None,
            })

    return history

# %%
def apply_sampling(X, y, random_state=42):
    """
    Applies RUS, ROS, and SMOTE to the input data.
    Returns a dict of { method_name: (X_resampled, y_resampled) }
    including the original data.
    """
    rus   = RandomUnderSampler(random_state=random_state)
    ros   = RandomOverSampler(random_state=random_state)
    smote = SMOTE(random_state=random_state)

    X_rus,   y_rus   = rus.fit_resample(X, y)
    X_ros,   y_ros   = ros.fit_resample(X, y)
    X_smote, y_smote = smote.fit_resample(X, y)

    sampling_methods = {
        "Original"             : (X,       y),
        "Random Undersampling" : (X_rus,   y_rus),
        "Random Oversampling"  : (X_ros,   y_ros),
        "SMOTE"                : (X_smote, y_smote),
    }

    # ── Print class distributions
    for method_name, (X_s, y_s) in sampling_methods.items():
        print(f"{method_name:25s} class distribution: {np.bincount(y_s.astype(int))}")

    return sampling_methods

# %%
def evaluate_active_learning(history, clf_name="", verbose=True):
    """
    Takes raw history from run_active_learning() and computes
    mean ± std across all iterations for each metric.
    Returns a single summary dict per classifier.
    """
    fold_metrics = {
        'accuracy' : [], 'precision': [], 'recall'   : [],
        'f1_score' : [], 'gmean'    : [], 'mcc'      : [], 'auc': []
    }

    # Helper function to get cumulative mean and std from a list of values
    def get_cum_stats(vals):
        if not vals:
            return 0.0, 0.0
        mean_val = np.mean(vals)
        std_val = np.std(vals) if len(vals) > 1 else 0.0 # Std is 0 for single element, or use 0.0 as placeholder
        return mean_val, std_val

    for i, entry in enumerate(history):
        y_test  = entry['y_test']
        y_pred  = entry['y_pred']
        y_score = entry['y_score']

        fold_metrics['accuracy' ].append(accuracy_score(y_test, y_pred))
        fold_metrics['precision'].append(precision_score(y_test, y_pred, average='weighted', zero_division=0))
        fold_metrics['recall'   ].append(recall_score(y_test, y_pred,    average='weighted', zero_division=0))
        fold_metrics['f1_score' ].append(f1_score(y_test, y_pred,        average='weighted', zero_division=0))
        fold_metrics['gmean'    ].append(g_mean(y_test, y_pred))
        fold_metrics['mcc'      ].append(matthews_corrcoef(y_test, y_pred))

        # ── AUC
        if y_score is not None:
            try:
                n_classes = len(np.unique(y_test))
                if n_classes == 2:
                    auc = roc_auc_score(y_test, y_score[:, 1])
                else:
                    auc = roc_auc_score(y_test, y_score,
                                        multi_class='ovr', average='macro',
                                        labels=np.unique(y_test))
                fold_metrics['auc'].append(auc)
            except Exception:
                fold_metrics['auc'].append(None)
        else:
            fold_metrics['auc'].append(None)

        if verbose:
            # Calculate cumulative mean and std for metrics up to this iteration
            acc_m_cum, acc_s_cum = get_cum_stats(fold_metrics['accuracy'])
            f1_m_cum,  f1_s_cum  = get_cum_stats(fold_metrics['f1_score'])
            gm_m_cum,  gm_s_cum  = get_cum_stats(fold_metrics['gmean'])
            mcc_m_cum, mcc_s_cum = get_cum_stats(fold_metrics['mcc'])

            auc_values_for_cum_stats = [v for v in fold_metrics['auc'] if v is not None]
            auc_m_cum, auc_s_cum = get_cum_stats(auc_values_for_cum_stats)

            print(f"  [{clf_name}] Iter {entry['iteration']:>2} | "
                  f"Labeled={entry['labeled_samples']:>3} | "
                  f"Acc={acc_m_cum:.4f}±{acc_s_cum:.4f} | F1={f1_m_cum:.4f}±{f1_s_cum:.4f} | "
                  f"G-Mean={gm_m_cum:.4f}±{gm_s_cum:.4f} | MCC={mcc_m_cum:.4f}±{mcc_s_cum:.4f}" +
                  (f" | AUC={auc_m_cum:.4f}±{auc_s_cum:.4f}" if auc_values_for_cum_stats else " | AUC=N/A"))

    def agg(vals):
        if not vals:
            return None, None
        return round(float(np.mean(vals)), 4), round(float(np.std(vals)), 4)

    acc_m,  acc_s  = agg(fold_metrics['accuracy'])
    prec_m, prec_s = agg(fold_metrics['precision'])
    rec_m,  rec_s  = agg(fold_metrics['recall'])
    f1_m,   f1_s   = agg(fold_metrics['f1_score'])
    gm_m,   gm_s   = agg(fold_metrics['gmean'])
    mcc_m,  mcc_s  = agg(fold_metrics['mcc'])
    auc_m,  auc_s  = agg([v for v in fold_metrics['auc'] if v is not None]) # Filter None for AUC calc

    summary = {
        'Classifier'      : clf_name,
        'Accuracy'        : acc_m,  'Accuracy_SD'  : acc_s,
        'Precision'       : prec_m, 'Precision_SD' : prec_s,
        'Recall'          : rec_m,  'Recall_SD'    : rec_s,
        'F1_Score'        : f1_m,   'F1_Score_SD'  : f1_s,
        'G_Mean'          : gm_m,   'G_Mean_SD'    : gm_s,
        'MCC'             : mcc_m,  'MCC_SD'       : mcc_s,
        'AUC'             : auc_m,  'AUC_SD'       : auc_s,
    }

    if verbose:
        print(f"\n  ── Final Summary [{clf_name}] ──────────────────────────────")
        print(f"     Acc={acc_m:.4f}±{acc_s:.4f} | "
              f"F1={f1_m:.4f}±{f1_s:.4f} | "
              f"G-Mean={gm_m:.4f}±{gm_s:.4f} | "
              f"MCC={mcc_m:.4f}±{mcc_s:.4f} | "
              f"AUC={auc_m:.4f}±{auc_s:.4f}" if auc_m is not None else "AUC=N/A")

    return summary

# %%
def run_all(sampling_methods: dict, classifiers: dict,
            n_iterations=10, initial_pool=500, verbose=True):
    """
    Returns: nested dict  all_results[method][clf] = summary_dict
    Also returns a combined DataFrame for easy tabular display.
    """
    all_results = {}
    all_rows    = []

    for method_name, (X_data, y_data) in sampling_methods.items():
        all_results[method_name] = {}

        for clf_name, clf in classifiers.items():
            print(f"\n=== Active Learning: {clf_name} | {method_name} ===")

            raw_history = run_active_learning(
                X_data, y_data, clf,
                initial_pool=initial_pool,
                n_iterations=n_iterations,
            )
            summary = evaluate_active_learning(raw_history, clf_name=clf_name, verbose=verbose)
            summary['Method'] = method_name

            all_results[method_name][clf_name] = summary
            all_rows.append(summary)

    df = pd.DataFrame(all_rows)
    metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'G_Mean', 'MCC', 'AUC']
    for m in metrics:
        df[f'{m}_fmt'] = df.apply(
            lambda r: f"{r[m]:.4f} ± {r[f'{m}_SD']:.4f}"
            if r[m] is not None else "N/A", axis=1
        )

    display_cols = ['Method', 'Classifier'] + [f'{m}_fmt' for m in metrics]
    display_df   = df[display_cols].rename(columns={f'{m}_fmt': m for m in metrics})

    return all_results, display_df

# %%
sampling_methods = apply_sampling(X, y)
all_results, summary_df = run_all(sampling_methods, classifiers,
                                   n_iterations=10, initial_pool=500)
print(summary_df.to_string(index=False))
# Out:
# Original                  class distribution: [333 375 160 265 234 390 248 264 325 251 262 159 345 207 297 405 232 248]
# Random Undersampling      class distribution: [159 159 159 159 159 159 159 159 159 159 159 159 159 159 159 159 159 159]
# Random Oversampling       class distribution: [405 405 405 405 405 405 405 405 405 405 405 405 405 405 405 405 405 405]
# SMOTE                     class distribution: [405 405 405 405 405 405 405 405 405 405 405 405 405 405 405 405 405 405]
#
# === Active Learning: Logistic Regression | Original ===
#   [Logistic Regression] Iter  1 | Labeled=501 | Acc=0.8540±0.0000 | F1=0.8502±0.0000 | G-Mean=0.8092±0.0000 | MCC=0.8451±0.0000 | AUC=0.9886±0.0000
#   [Logistic Regression] Iter  2 | Labeled=502 | Acc=0.8525±0.0015 | F1=0.8487±0.0015 | G-Mean=0.8076±0.0016 | MCC=0.8435±0.0016 | AUC=0.9887±0.0001
#   [Logistic Regression] Iter  3 | Labeled=503 | Acc=0.8523±0.0012 | F1=0.8485±0.0013 | G-Mean=0.8074±0.0013 | MCC=0.8433±0.0013 | AUC=0.9887±0.0001
# ...

# %%
output_dir = "active_learning_results"
os.makedirs(output_dir, exist_ok=True)

for method_name in summary_df['Method'].unique():
    # Filter the summary_df for the current sampling method
    filtered_df = summary_df[summary_df['Method'] == method_name]

    # Clean the method name for use in a filename
    clean_method_name = method_name.replace(' ', '_').replace('(', '').replace(')', '')

    # Construct the filename
    filename = f"AL_{clean_method_name}.csv"
    filepath = os.path.join(output_dir, filename)

    # Save to CSV
    filtered_df.to_csv(filepath, index=False)
    print(f"Saved results for {method_name} to {filepath}")
