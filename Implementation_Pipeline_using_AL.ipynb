# %% [markdown]
# <a href="https://colab.research.google.com/github/muajnstu/Bank-Marketing-using-rough-set-approach/blob/main/Implementation_Pipeline_using_AL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Run this only once in your environment (e.g., terminal or notebook cell)
# !pip install -q imbalanced-learn catboost xgboost lightgbm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 7.7 MB/s eta 0:00:00

# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,
    confusion_matrix, matthews_corrcoef, classification_report, roc_curve, auc
)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, RidgeClassifier, Lasso, ElasticNet, Perceptron
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    StackingClassifier, VotingClassifier,
    RandomForestClassifier, GradientBoostingClassifier,
    ExtraTreesClassifier, BaggingClassifier, AdaBoostClassifier
)
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.gaussian_process import GaussianProcessClassifier

import warnings
warnings.filterwarnings("ignore", message="'force_all_finite' was renamed to 'ensure_all_finite'")
warnings.filterwarnings("ignore", message="Parameters: { \"use_label_encoder\" } are not used.")
warnings.filterwarnings("ignore", message=".*does not have valid feature names.*")

# %%
# --- Base estimators reused across ensembles ---
base_estimators = [
    ("lr",  LogisticRegression(max_iter=1000)),
    ("rf",  RandomForestClassifier(random_state=42)),
    ("gb",  GradientBoostingClassifier(random_state=42)),
    ("xgb", XGBClassifier(eval_metric='logloss', random_state=42, use_label_encoder=False)),
    ("lgbm",LGBMClassifier(verbosity=-1)),
    ("svm", SVC(probability=True)),
    ("et",  ExtraTreesClassifier(random_state=42)),
    ("knn", KNeighborsClassifier()),
]

classifiers = {
    # ── Original classifiers ──────────────────────────────────────────────────
    "Logistic Regression":   LogisticRegression(max_iter=1000),
    "SVM":                   SVC(),
    "Naive Bayes":           GaussianNB(),
    "K-Nearest Neighbors":   KNeighborsClassifier(),
    "Decision Tree":         DecisionTreeClassifier(),
    "Random Forest":         RandomForestClassifier(random_state=42),
    "Gradient Boosting":     GradientBoostingClassifier(random_state=42),
    "XGBoost":               XGBClassifier(eval_metric='logloss', random_state=42, enable_categorical=True),
    "LightGBM":              LGBMClassifier(verbosity=-1),
    "CatBoost":              CatBoostClassifier(verbose=0, random_state=42),
    "AdaBoost":              AdaBoostClassifier(random_state=42),
    "Extra Trees":           ExtraTreesClassifier(random_state=42),
    "Ridge Classifier":      RidgeClassifier(),
    "Perceptron":            Perceptron(),
    "Bagging Classifier":    BaggingClassifier(random_state=42),
    "GaussianNB":            GaussianNB(),

    # ── Stacking ──────────────────────────────────────────────────────────────
    "Stacking": StackingClassifier(
        estimators=base_estimators,
        final_estimator=LogisticRegression(max_iter=1000),
        cv=5,
        passthrough=False,
        n_jobs=-1
    ),

    # ── Hard Voting ───────────────────────────────────────────────────────────
    "Hard Voting": VotingClassifier(
        estimators=base_estimators,
        voting='hard',
        n_jobs=-1
    ),

    # ── Soft Voting ───────────────────────────────────────────────────────────
    "Soft Voting": VotingClassifier(
        estimators=base_estimators,
        voting='soft',
        n_jobs=-1
    ),

    # ── Weighted Soft Voting ──────────────────────────────────────────────────
    "Weighted Voting": VotingClassifier(
        estimators=base_estimators,
        voting='soft',
        weights=[
            3,   # lr   – reliable baseline
            4,   # rf   – strong ensemble
            4,   # gb   – strong ensemble
            5,   # xgb  – typically best single model
            5,   # lgbm – typically best single model
            2,   # svm  – good but slower to calibrate
            3,   # et   – good diversity
            2,   # knn  – useful diversity, lower weight
        ],
        n_jobs=-1
    ),

    # ── Adding / Averaging (soft alias) ──────────────────────────────────────
    "Adding (Avg Probabilities)": VotingClassifier(
        estimators=base_estimators,
        voting='soft',
        weights=[1, 1, 1, 1, 1, 1, 1, 1],
        n_jobs=-1
    ),
}

# %% [markdown]
# # **Step 2: Load Dataset, Remove Outliers, Drop Features, and Scale Data**

# %%
# Load dataset
data = pd.read_csv('https://raw.githubusercontent.com/muajnstu/Bank-Marketing-using-rough-set-approach/refs/heads/main/MicroClustered_bank_data.csv')


# Separate features and target
X = data.drop('Personal_Loan', axis=1)
y = data['Personal_Loan']

# %% [markdown]
# # **Step 3: Handle Class Imbalance with Multiple Sampling Techniques**

# %%
# Random Undersampling
rus = RandomUnderSampler(random_state=42)
ros = RandomOverSampler(random_state=42)
smote = SMOTE(random_state=42)
# adasyn = ADASYN(random_state=42) # Removed ADASYN due to error

X_rus, y_rus = rus.fit_resample(X, y)
X_ros, y_ros = ros.fit_resample(X, y)
X_smote, y_smote = smote.fit_resample(X, y)
# X_adasyn, y_adasyn = adasyn.fit_resample(X_scaled, y) # Removed ADASYN due to error


# Print class distributions
print(f"Original class distribution: {np.bincount(y.astype(int))}")
print(f"After Random Undersampling: {np.bincount(y_rus.astype(int))}")
print(f"After Random Oversampling: {np.bincount(y_ros.astype(int))}")
print(f"After SMOTE: {np.bincount(y_smote.astype(int))}")
# print(f"After ADASYN: {np.bincount(y_adasyn.astype(int))}") # Removed ADASYN due to error
# Out:
# Original class distribution: [333 375 160 265 234 390 248 264 325 251 262 159 345 207 297 405 232 248]
# After Random Undersampling: [159 159 159 159 159 159 159 159 159 159 159 159 159 159 159 159 159 159]
# After Random Oversampling: [405 405 405 405 405 405 405 405 405 405 405 405 405 405 405 405 405 405]
# After SMOTE: [405 405 405 405 405 405 405 405 405 405 405 405 405 405 405 405 405 405]

# %% [markdown]
# # **Step 5: Run Active Learning on Different sampled Dataset for All Classifiers**

# %%
def remove_instance(X, y, idx):
    X_new = np.delete(X, idx, axis=0)
    y_new = np.delete(y, idx, axis=0)
    return X_new, y_new


def g_mean(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    recalls = []
    for i in range(cm.shape[0]):
        tp = cm[i, i]
        fn = np.sum(cm[i, :]) - tp
        recall_i = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        recalls.append(recall_i)

    valid_recalls = [r for r in recalls if r > 0]
    if not valid_recalls:
        return 0.0

    product = 1.0
    for r in valid_recalls:
        product *= r
    return product ** (1.0 / len(valid_recalls))


# Define result dictionaries
results_active_learning         = {}
results_active_learning_rus     = {}
results_active_learning_ros     = {}
results_active_learning_smote   = {}

# Dictionary mapping sampling method names to data and result storage
sampling_methods = {
    "Original"             : (X, y, results_active_learning),
    "Random Undersampling" : (X_rus, y_rus, results_active_learning_rus),
    "Random Oversampling"  : (X_ros, y_ros, results_active_learning_ros),
    "SMOTE"                : (X_smote, y_smote, results_active_learning_smote)
}

# Loop through each sampling method
for method_name, (X_data, y_data, result_dict) in sampling_methods.items():

    # y is already 0/1 integers — no LabelEncoder needed
    y_data = np.array(y_data, dtype=int)
    unique_classes = np.unique(y_data)

    for name, clf in classifiers.items():
        print(f"\n=== Active Learning: {name} | {method_name} ===")

        X_train_full, X_test, y_train_full, y_test = train_test_split(
            X_data, y_data,
            test_size=0.20,
            random_state=42,
            stratify=y_data        # ensures class balance in split
        )

        np.random.seed(42)

        # --- Seed: one sample per class to guarantee all classes from iteration 1 ---
        seed_idx = []
        for c in unique_classes:
            class_indices = np.where(y_train_full == c)[0]
            seed_idx.append(class_indices[0])
        seed_idx = np.array(seed_idx)

        # --- Fill remaining slots up to initial pool size of 60 ---
        remaining_pool = np.array([i for i in range(len(X_train_full)) if i not in seed_idx])
        n_extra = max(0, 500 - len(seed_idx))
        extra_idx = np.random.choice(remaining_pool, size=n_extra, replace=False)
        labeled_idx = np.concatenate([seed_idx, extra_idx])

        # --- Build labeled and unlabeled sets ---
        if hasattr(X_train_full, 'iloc'):
            X_labeled   = X_train_full.iloc[labeled_idx].values
            X_unlabeled = X_train_full.iloc[[i for i in range(len(X_train_full)) if i not in labeled_idx]].values
        else:
            X_labeled   = X_train_full[labeled_idx]
            X_unlabeled = X_train_full[[i for i in range(len(X_train_full)) if i not in labeled_idx]]

        y_labeled   = y_train_full[labeled_idx]
        y_unlabeled = y_train_full[np.array([i for i in range(len(X_train_full)) if i not in labeled_idx])]

        if hasattr(X_test, 'values'):
            X_test = X_test.values

        history = []

        # --- Active Learning Loop ---
        for i in range(10):
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")

                clf.fit(X_labeled, y_labeled)

                # Uncertainty sampling
                if hasattr(clf, "predict_proba"):
                    probs       = clf.predict_proba(X_unlabeled)
                    uncertainty = 1 - np.max(probs, axis=1)
                else:
                    uncertainty = np.random.rand(len(X_unlabeled))

                # Query most uncertain sample
                query_idx = np.argmax(uncertainty)

                # Move queried sample from unlabeled → labeled
                X_labeled   = np.vstack([X_labeled, X_unlabeled[query_idx].reshape(1, -1)])
                y_labeled   = np.append(y_labeled, y_unlabeled[query_idx])
                X_unlabeled, y_unlabeled = remove_instance(X_unlabeled, y_unlabeled, query_idx)

                # Evaluate
                y_pred      = clf.predict(X_test)
                acc         = accuracy_score(y_test, y_pred)
                prec        = precision_score(y_test, y_pred, average='weighted', zero_division=0)
                rec         = recall_score(y_test, y_pred, average='weighted', zero_division=0)
                f1          = f1_score(y_test, y_pred, average='weighted', zero_division=0)
                gmean_score = g_mean(y_test, y_pred)
                mcc         = matthews_corrcoef(y_test, y_pred)

                history.append({
                    'iteration'      : i + 1,
                    'accuracy'       : acc,
                    'precision'      : prec,
                    'recall'         : rec,
                    'f1_score'       : f1,
                    'gmean'          : gmean_score,
                    'mcc'            : mcc,
                    'labeled_samples': len(X_labeled)
                })

                print(f"  [{name}] Iter {i+1:>2} | "
                      f"Labeled={len(X_labeled):>3} | "
                      f"Acc={acc:.4f} | F1={f1:.4f} | "
                      f"G-Mean={gmean_score:.4f} | MCC={mcc:.4f}")

        result_dict[name] = history
# Out:
# === Active Learning: Logistic Regression | Original ===
#   [Logistic Regression] Iter  1 | Labeled=501 | Acc=0.8540 | F1=0.8502 | G-Mean=0.8092 | MCC=0.8451
#   [Logistic Regression] Iter  2 | Labeled=502 | Acc=0.8510 | F1=0.8472 | G-Mean=0.8061 | MCC=0.8419
#   [Logistic Regression] Iter  3 | Labeled=503 | Acc=0.8520 | F1=0.8481 | G-Mean=0.8068 | MCC=0.8430
#   [Logistic Regression] Iter  4 | Labeled=504 | Acc=0.8490 | F1=0.8446 | G-Mean=0.7974 | MCC=0.8398
#   [Logistic Regression] Iter  5 | Labeled=505 | Acc=0.8540 | F1=0.8501 | G-Mean=0.8054 | MCC=0.8451
#   [Logistic Regression] Iter  6 | Labeled=506 | Acc=0.8560 | F1=0.8521 | G-Mean=0.8070 | MCC=0.8472
#   [Logistic Regression] Iter  7 | Labeled=507 | Acc=0.8540 | F1=0.8498 | G-Mean=0.8052 | MCC=0.8451
#   [Logistic Regression] Iter  8 | Labeled=508 | Acc=0.8520 | F1=0.8473 | G-Mean=0.7999 | MCC=0.8430
#   [Logistic Regression] Iter  9 | Labeled=509 | Acc=0.8550 | F1=0.8502 | G-Mean=0.8035 | MCC=0.8462
#   [Logistic Regression] Iter 10 | Labeled=510 | Acc=0.8600 | F1=0.8554 | G-Mean=0.8077 | MCC=0.8515
#
# === Active Learning: SVM | Original ===
#   [SVM] Iter  1 | Labeled=501 | Acc=0.2360 | F1=0.1375 | G-Mean=0.2351 | MCC=0.1980
#   [SVM] Iter  2 | Labeled=502 | Acc=0.2360 | F1=0.1377 | G-Mean=0.2351 | MCC=0.1978
#   [SVM] Iter  3 | Labeled=503 | Acc=0.2360 | F1=0.1402 | G-Mean=0.1772 | MCC=0.1974
#   [SVM] Iter  4 | Labeled=504 | Acc=0.2360 | F1=0.1402 | G-Mean=0.1772 | MCC=0.1978
#   [SVM] Iter  5 | Labeled=505 | Acc=0.2360 | F1=0.1402 | G-Mean=0.1772 | MCC=0.1978
#   [SVM] Iter  6 | Labeled=506 | Acc=0.2350 | F1=0.1382 | G-Mean=0.2325 | MCC=0.1967
#   [SVM] Iter  7 | Labeled=507 | Acc=0.2350 | F1=0.1382 | G-Mean=0.2325 | MCC=0.1967
#   [SVM] Iter  8 | Labeled=508 | Acc=0.2340 | F1=0.1371 | G-Mean=0.2315 | MCC=0.1959
#   [SVM] Iter  9 | Labeled=509 | Acc=0.2340 | F1=0.1371 | G-Mean=0.2315 | MCC=0.1960
#   [SVM] Iter 10 | Labeled=510 | Acc=0.2350 | F1=0.1375 | G-Mean=0.2319 | MCC=0.1972
#
# === Active Learning: Naive Bayes | Original ===
#   [Naive Bayes] Iter  1 | Labeled=501 | Acc=0.7040 | F1=0.6735 | G-Mean=0.5449 | MCC=0.6887
#   [Naive Bayes] Iter  2 | Labeled=502 | Acc=0.7040 | F1=0.6735 | G-Mean=0.5449 | MCC=0.6887
#   [Naive Bayes] Iter  3 | Labeled=503 | Acc=0.7050 | F1=0.6745 | G-Mean=0.5455 | MCC=0.6898
#   [Naive Bayes] Iter  4 | Labeled=504 | Acc=0.7050 | F1=0.6745 | G-Mean=0.5455 | MCC=0.6898
#   [Naive Bayes] Iter  5 | Labeled=505 | Acc=0.7050 | F1=0.6745 | G-Mean=0.5455 | MCC=0.6898
#   [Naive Bayes] Iter  6 | Labeled=506 | Acc=0.7060 | F1=0.6761 | G-Mean=0.5502 | MCC=0.6908
#   [Naive Bayes] Iter  7 | Labeled=507 | Acc=0.6990 | F1=0.6701 | G-Mean=0.5451 | MCC=0.6835
#   [Naive Bayes] Iter  8 | Labeled=508 | Acc=0.6980 | F1=0.6684 | G-Mean=0.5430 | MCC=0.6824
#   [Naive Bayes] Iter  9 | Labeled=509 | Acc=0.6970 | F1=0.6672 | G-Mean=0.5415 | MCC=0.6814
#   [Naive Bayes] Iter 10 | Labeled=510 | Acc=0.6970 | F1=0.6672 | G-Mean=0.5415 | MCC=0.6814
#
# === Active Learning: K-Nearest Neighbors | Original ===
#   [K-Nearest Neighbors] Iter  1 | Labeled=501 | Acc=0.2370 | F1=0.2263 | G-Mean=0.1783 | MCC=0.1880
#   [K-Nearest Neighbors] Iter  2 | Labeled=502 | Acc=0.2370 | F1=0.2262 | G-Mean=0.1783 | MCC=0.1880
#   [K-Nearest Neighbors] Iter  3 | Labeled=503 | Acc=0.2380 | F1=0.2271 | G-Mean=0.1788 | MCC=0.1890
#   [K-Nearest Neighbors] Iter  4 | Labeled=504 | Acc=0.2370 | F1=0.2262 | G-Mean=0.1782 | MCC=0.1880
#   [K-Nearest Neighbors] Iter  5 | Labeled=505 | Acc=0.2370 | F1=0.2261 | G-Mean=0.1782 | MCC=0.1880
#   [K-Nearest Neighbors] Iter  6 | Labeled=506 | Acc=0.2370 | F1=0.2261 | G-Mean=0.1782 | MCC=0.1880
#   [K-Nearest Neighbors] Iter  7 | Labeled=507 | Acc=0.2360 | F1=0.2254 | G-Mean=0.1774 | MCC=0.1869
#   [K-Nearest Neighbors] Iter  8 | Labeled=508 | Acc=0.2360 | F1=0.2248 | G-Mean=0.1766 | MCC=0.1869
#   [K-Nearest Neighbors] Iter  9 | Labeled=509 | Acc=0.2350 | F1=0.2235 | G-Mean=0.1757 | MCC=0.1858
#   [K-Nearest Neighbors] Iter 10 | Labeled=510 | Acc=0.2370 | F1=0.2251 | G-Mean=0.1768 | MCC=0.1880
#
# === Active Learning: Decision Tree | Original ===
#   [Decision Tree] Iter  1 | Labeled=501 | Acc=0.7990 | F1=0.7959 | G-Mean=0.7300 | MCC=0.7869
#   [Decision Tree] Iter  2 | Labeled=502 | Acc=0.7910 | F1=0.7935 | G-Mean=0.7256 | MCC=0.7784
#   [Decision Tree] Iter  3 | Labeled=503 | Acc=0.7850 | F1=0.7835 | G-Mean=0.7091 | MCC=0.7718
#   [Decision Tree] Iter  4 | Labeled=504 | Acc=0.7800 | F1=0.7782 | G-Mean=0.7050 | MCC=0.7668
#   [Decision Tree] Iter  5 | Labeled=505 | Acc=0.7850 | F1=0.7794 | G-Mean=0.6761 | MCC=0.7721
#   [Decision Tree] Iter  6 | Labeled=506 | Acc=0.7970 | F1=0.7981 | G-Mean=0.7243 | MCC=0.7846
#   [Decision Tree] Iter  7 | Labeled=507 | Acc=0.7750 | F1=0.7733 | G-Mean=0.6884 | MCC=0.7611
#   [Decision Tree] Iter  8 | Labeled=508 | Acc=0.8010 | F1=0.8018 | G-Mean=0.7321 | MCC=0.7888
#   [Decision Tree] Iter  9 | Labeled=509 | Acc=0.7930 | F1=0.7939 | G-Mean=0.7198 | MCC=0.7804
#   [Decision Tree] Iter 10 | Labeled=510 | Acc=0.7990 | F1=0.7966 | G-Mean=0.7184 | MCC=0.7868
#
# === Active Learning: Random Forest | Original ===
#   [Random Forest] Iter  1 | Labeled=501 | Acc=0.8470 | F1=0.8378 | G-Mean=0.7821 | MCC=0.8379
#   [Random Forest] Iter  2 | Labeled=502 | Acc=0.8520 | F1=0.8447 | G-Mean=0.7953 | MCC=0.8432
#   [Random Forest] Iter  3 | Labeled=503 | Acc=0.8570 | F1=0.8507 | G-Mean=0.8065 | MCC=0.8485
#   [Random Forest] Iter  4 | Labeled=504 | Acc=0.8500 | F1=0.8422 | G-Mean=0.7919 | MCC=0.8411
#   [Random Forest] Iter  5 | Labeled=505 | Acc=0.8540 | F1=0.8465 | G-Mean=0.8001 | MCC=0.8453
#   [Random Forest] Iter  6 | Labeled=506 | Acc=0.8590 | F1=0.8522 | G-Mean=0.8054 | MCC=0.8506
#   [Random Forest] Iter  7 | Labeled=507 | Acc=0.8550 | F1=0.8468 | G-Mean=0.7931 | MCC=0.8464
#   [Random Forest] Iter  8 | Labeled=508 | Acc=0.8640 | F1=0.8580 | G-Mean=0.8126 | MCC=0.8559
#   [Random Forest] Iter  9 | Labeled=509 | Acc=0.8600 | F1=0.8531 | G-Mean=0.8038 | MCC=0.8516
#   [Random Forest] Iter 10 | Labeled=510 | Acc=0.8570 | F1=0.8492 | G-Mean=0.7945 | MCC=0.8485
#
# === Active Learning: Gradient Boosting | Original ===
#   [Gradient Boosting] Iter  1 | Labeled=501 | Acc=0.8340 | F1=0.8232 | G-Mean=0.7547 | MCC=0.8242
#   [Gradient Boosting] Iter  2 | Labeled=502 | Acc=0.8390 | F1=0.8294 | G-Mean=0.7635 | MCC=0.8296
#   [Gradient Boosting] Iter  3 | Labeled=503 | Acc=0.8320 | F1=0.8211 | G-Mean=0.7462 | MCC=0.8221
#   [Gradient Boosting] Iter  4 | Labeled=504 | Acc=0.8290 | F1=0.8180 | G-Mean=0.7420 | MCC=0.8188
#   [Gradient Boosting] Iter  5 | Labeled=505 | Acc=0.8270 | F1=0.8136 | G-Mean=0.7235 | MCC=0.8168
#   [Gradient Boosting] Iter  6 | Labeled=506 | Acc=0.8360 | F1=0.8254 | G-Mean=0.7543 | MCC=0.8264
#   [Gradient Boosting] Iter  7 | Labeled=507 | Acc=0.8350 | F1=0.8247 | G-Mean=0.7567 | MCC=0.8254
#   [Gradient Boosting] Iter  8 | Labeled=508 | Acc=0.8390 | F1=0.8297 | G-Mean=0.7638 | MCC=0.8295
#   [Gradient Boosting] Iter  9 | Labeled=509 | Acc=0.8420 | F1=0.8328 | G-Mean=0.7681 | MCC=0.8327
#   [Gradient Boosting] Iter 10 | Labeled=510 | Acc=0.8420 | F1=0.8322 | G-Mean=0.7646 | MCC=0.8327
#
# === Active Learning: XGBoost | Original ===
#   [XGBoost] Iter  1 | Labeled=501 | Acc=0.8580 | F1=0.8538 | G-Mean=0.8016 | MCC=0.8493
#   [XGBoost] Iter  2 | Labeled=502 | Acc=0.8680 | F1=0.8656 | G-Mean=0.8257 | MCC=0.8599
#   [XGBoost] Iter  3 | Labeled=503 | Acc=0.8660 | F1=0.8633 | G-Mean=0.8213 | MCC=0.8577
#   [XGBoost] Iter  4 | Labeled=504 | Acc=0.8670 | F1=0.8634 | G-Mean=0.8201 | MCC=0.8588
#   [XGBoost] Iter  5 | Labeled=505 | Acc=0.8690 | F1=0.8655 | G-Mean=0.8213 | MCC=0.8610
#   [XGBoost] Iter  6 | Labeled=506 | Acc=0.8650 | F1=0.8612 | G-Mean=0.8165 | MCC=0.8567
#   [XGBoost] Iter  7 | Labeled=507 | Acc=0.8670 | F1=0.8628 | G-Mean=0.8157 | MCC=0.8588
#   [XGBoost] Iter  8 | Labeled=508 | Acc=0.8680 | F1=0.8642 | G-Mean=0.8205 | MCC=0.8599
#   [XGBoost] Iter  9 | Labeled=509 | Acc=0.8680 | F1=0.8650 | G-Mean=0.8245 | MCC=0.8599
#   [XGBoost] Iter 10 | Labeled=510 | Acc=0.8700 | F1=0.8659 | G-Mean=0.8182 | MCC=0.8620
#
# === Active Learning: LightGBM | Original ===
#   [LightGBM] Iter  1 | Labeled=501 | Acc=0.8710 | F1=0.8691 | G-Mean=0.8434 | MCC=0.8632
#   [LightGBM] Iter  2 | Labeled=502 | Acc=0.8770 | F1=0.8750 | G-Mean=0.8510 | MCC=0.8695
#   [LightGBM] Iter  3 | Labeled=503 | Acc=0.8730 | F1=0.8707 | G-Mean=0.8453 | MCC=0.8653
#   [LightGBM] Iter  4 | Labeled=504 | Acc=0.8730 | F1=0.8705 | G-Mean=0.8445 | MCC=0.8653
#   [LightGBM] Iter  5 | Labeled=505 | Acc=0.8700 | F1=0.8677 | G-Mean=0.8398 | MCC=0.8621
#   [LightGBM] Iter  6 | Labeled=506 | Acc=0.8800 | F1=0.8782 | G-Mean=0.8534 | MCC=0.8726
#   [LightGBM] Iter  7 | Labeled=507 | Acc=0.8800 | F1=0.8783 | G-Mean=0.8567 | MCC=0.8727
#   [LightGBM] Iter  8 | Labeled=508 | Acc=0.8750 | F1=0.8735 | G-Mean=0.8516 | MCC=0.8674
#   [LightGBM] Iter  9 | Labeled=509 | Acc=0.8710 | F1=0.8697 | G-Mean=0.8460 | MCC=0.8632
#   [LightGBM] Iter 10 | Labeled=510 | Acc=0.8810 | F1=0.8796 | G-Mean=0.8582 | MCC=0.8737
#
# === Active Learning: CatBoost | Original ===
#   [CatBoost] Iter  1 | Labeled=501 | Acc=0.8830 | F1=0.8811 | G-Mean=0.8590 | MCC=0.8758
#   [CatBoost] Iter  2 | Labeled=502 | Acc=0.8820 | F1=0.8799 | G-Mean=0.8590 | MCC=0.8748
#   [CatBoost] Iter  3 | Labeled=503 | Acc=0.8820 | F1=0.8802 | G-Mean=0.8584 | MCC=0.8747
#   [CatBoost] Iter  4 | Labeled=504 | Acc=0.8880 | F1=0.8860 | G-Mean=0.8665 | MCC=0.8811
#   [CatBoost] Iter  5 | Labeled=505 | Acc=0.8840 | F1=0.8820 | G-Mean=0.8611 | MCC=0.8769
#   [CatBoost] Iter  6 | Labeled=506 | Acc=0.8830 | F1=0.8812 | G-Mean=0.8591 | MCC=0.8758
#   [CatBoost] Iter  7 | Labeled=507 | Acc=0.8810 | F1=0.8789 | G-Mean=0.8557 | MCC=0.8737
#   [CatBoost] Iter  8 | Labeled=508 | Acc=0.8820 | F1=0.8801 | G-Mean=0.8575 | MCC=0.8747
#   [CatBoost] Iter  9 | Labeled=509 | Acc=0.8800 | F1=0.8778 | G-Mean=0.8537 | MCC=0.8726
#   [CatBoost] Iter 10 | Labeled=510 | Acc=0.8790 | F1=0.8766 | G-Mean=0.8512 | MCC=0.8715
#
# === Active Learning: AdaBoost | Original ===
#   [AdaBoost] Iter  1 | Labeled=501 | Acc=0.2730 | F1=0.1538 | G-Mean=0.3940 | MCC=0.2368
#   [AdaBoost] Iter  2 | Labeled=502 | Acc=0.2550 | F1=0.1631 | G-Mean=0.2016 | MCC=0.2184
#   [AdaBoost] Iter  3 | Labeled=503 | Acc=0.2970 | F1=0.1788 | G-Mean=0.3104 | MCC=0.2683
#   [AdaBoost] Iter  4 | Labeled=504 | Acc=0.3170 | F1=0.2025 | G-Mean=0.3248 | MCC=0.2810
#   [AdaBoost] Iter  5 | Labeled=505 | Acc=0.1760 | F1=0.0932 | G-Mean=0.1674 | MCC=0.1429
#   [AdaBoost] Iter  6 | Labeled=506 | Acc=0.2500 | F1=0.1436 | G-Mean=0.1868 | MCC=0.2111
#   [AdaBoost] Iter  7 | Labeled=507 | Acc=0.3790 | F1=0.2619 | G-Mean=0.3238 | MCC=0.3495
#   [AdaBoost] Iter  8 | Labeled=508 | Acc=0.3080 | F1=0.1898 | G-Mean=0.1406 | MCC=0.2771
#   [AdaBoost] Iter  9 | Labeled=509 | Acc=0.3120 | F1=0.1898 | G-Mean=0.2549 | MCC=0.2829
#   [AdaBoost] Iter 10 | Labeled=510 | Acc=0.3780 | F1=0.2851 | G-Mean=0.1762 | MCC=0.3423
#
# === Active Learning: Extra Trees | Original ===
#   [Extra Trees] Iter  1 | Labeled=501 | Acc=0.8530 | F1=0.8455 | G-Mean=0.7954 | MCC=0.8442
#   [Extra Trees] Iter  2 | Labeled=502 | Acc=0.8400 | F1=0.8305 | G-Mean=0.7709 | MCC=0.8306
#   [Extra Trees] Iter  3 | Labeled=503 | Acc=0.8450 | F1=0.8372 | G-Mean=0.7861 | MCC=0.8357
#   [Extra Trees] Iter  4 | Labeled=504 | Acc=0.8400 | F1=0.8313 | G-Mean=0.7765 | MCC=0.8304
#   [Extra Trees] Iter  5 | Labeled=505 | Acc=0.8380 | F1=0.8297 | G-Mean=0.7746 | MCC=0.8283
#   [Extra Trees] Iter  6 | Labeled=506 | Acc=0.8480 | F1=0.8392 | G-Mean=0.7805 | MCC=0.8389
#   [Extra Trees] Iter  7 | Labeled=507 | Acc=0.8420 | F1=0.8335 | G-Mean=0.7793 | MCC=0.8325
#   [Extra Trees] Iter  8 | Labeled=508 | Acc=0.8420 | F1=0.8341 | G-Mean=0.7814 | MCC=0.8325
#   [Extra Trees] Iter  9 | Labeled=509 | Acc=0.8430 | F1=0.8349 | G-Mean=0.7806 | MCC=0.8335
#   [Extra Trees] Iter 10 | Labeled=510 | Acc=0.8370 | F1=0.8277 | G-Mean=0.7691 | MCC=0.8272
#
# === Active Learning: Ridge Classifier | Original ===
#   [Ridge Classifier] Iter  1 | Labeled=501 | Acc=0.5880 | F1=0.5404 | G-Mean=0.4354 | MCC=0.5679
#   [Ridge Classifier] Iter  2 | Labeled=502 | Acc=0.5890 | F1=0.5418 | G-Mean=0.4376 | MCC=0.5690
#   [Ridge Classifier] Iter  3 | Labeled=503 | Acc=0.5910 | F1=0.5444 | G-Mean=0.4403 | MCC=0.5712
#   [Ridge Classifier] Iter  4 | Labeled=504 | Acc=0.5870 | F1=0.5403 | G-Mean=0.4364 | MCC=0.5670
#   [Ridge Classifier] Iter  5 | Labeled=505 | Acc=0.5900 | F1=0.5423 | G-Mean=0.4384 | MCC=0.5700
#   [Ridge Classifier] Iter  6 | Labeled=506 | Acc=0.5910 | F1=0.5432 | G-Mean=0.4391 | MCC=0.5711
#   [Ridge Classifier] Iter  7 | Labeled=507 | Acc=0.5900 | F1=0.5431 | G-Mean=0.4394 | MCC=0.5705
#   [Ridge Classifier] Iter  8 | Labeled=508 | Acc=0.5880 | F1=0.5412 | G-Mean=0.4396 | MCC=0.5684
#   [Ridge Classifier] Iter  9 | Labeled=509 | Acc=0.5880 | F1=0.5404 | G-Mean=0.4381 | MCC=0.5684
#   [Ridge Classifier] Iter 10 | Labeled=510 | Acc=0.5920 | F1=0.5456 | G-Mean=0.4424 | MCC=0.5727
#
# === Active Learning: Perceptron | Original ===
#   [Perceptron] Iter  1 | Labeled=501 | Acc=0.1870 | F1=0.1007 | G-Mean=0.5209 | MCC=0.1524
#   [Perceptron] Iter  2 | Labeled=502 | Acc=0.1440 | F1=0.0699 | G-Mean=0.3577 | MCC=0.1272
#   [Perceptron] Iter  3 | Labeled=503 | Acc=0.1320 | F1=0.0725 | G-Mean=0.1139 | MCC=0.0734
#   [Perceptron] Iter  4 | Labeled=504 | Acc=0.1590 | F1=0.0807 | G-Mean=0.3300 | MCC=0.1114
#   [Perceptron] Iter  5 | Labeled=505 | Acc=0.1930 | F1=0.1290 | G-Mean=0.2736 | MCC=0.1478
#   [Perceptron] Iter  6 | Labeled=506 | Acc=0.1740 | F1=0.1218 | G-Mean=0.2880 | MCC=0.1377
#   [Perceptron] Iter  7 | Labeled=507 | Acc=0.1510 | F1=0.1019 | G-Mean=0.2726 | MCC=0.1187
#   [Perceptron] Iter  8 | Labeled=508 | Acc=0.1500 | F1=0.0909 | G-Mean=0.1576 | MCC=0.1003
#   [Perceptron] Iter  9 | Labeled=509 | Acc=0.1540 | F1=0.0855 | G-Mean=0.2892 | MCC=0.1262
#   [Perceptron] Iter 10 | Labeled=510 | Acc=0.2280 | F1=0.1802 | G-Mean=0.2939 | MCC=0.1817
#
# === Active Learning: Bagging Classifier | Original ===
#   [Bagging Classifier] Iter  1 | Labeled=501 | Acc=0.8050 | F1=0.7943 | G-Mean=0.7179 | MCC=0.7933
#   [Bagging Classifier] Iter  2 | Labeled=502 | Acc=0.8070 | F1=0.7968 | G-Mean=0.7276 | MCC=0.7954
#   [Bagging Classifier] Iter  3 | Labeled=503 | Acc=0.8070 | F1=0.7975 | G-Mean=0.7299 | MCC=0.7952
#   [Bagging Classifier] Iter  4 | Labeled=504 | Acc=0.8110 | F1=0.8016 | G-Mean=0.7279 | MCC=0.7995
#   [Bagging Classifier] Iter  5 | Labeled=505 | Acc=0.8120 | F1=0.8032 | G-Mean=0.7327 | MCC=0.8006
#   [Bagging Classifier] Iter  6 | Labeled=506 | Acc=0.8160 | F1=0.8071 | G-Mean=0.7354 | MCC=0.8048
#   [Bagging Classifier] Iter  7 | Labeled=507 | Acc=0.8170 | F1=0.8099 | G-Mean=0.7490 | MCC=0.8059
#   [Bagging Classifier] Iter  8 | Labeled=508 | Acc=0.8180 | F1=0.8106 | G-Mean=0.7495 | MCC=0.8071
#   [Bagging Classifier] Iter  9 | Labeled=509 | Acc=0.8170 | F1=0.8094 | G-Mean=0.7468 | MCC=0.8060
#   [Bagging Classifier] Iter 10 | Labeled=510 | Acc=0.8220 | F1=0.8139 | G-Mean=0.7542 | MCC=0.8113
#
# === Active Learning: GaussianNB | Original ===
#   [GaussianNB] Iter  1 | Labeled=501 | Acc=0.7040 | F1=0.6735 | G-Mean=0.5449 | MCC=0.6887
#   [GaussianNB] Iter  2 | Labeled=502 | Acc=0.7040 | F1=0.6735 | G-Mean=0.5449 | MCC=0.6887
#   [GaussianNB] Iter  3 | Labeled=503 | Acc=0.7050 | F1=0.6745 | G-Mean=0.5455 | MCC=0.6898
#   [GaussianNB] Iter  4 | Labeled=504 | Acc=0.7050 | F1=0.6745 | G-Mean=0.5455 | MCC=0.6898
#   [GaussianNB] Iter  5 | Labeled=505 | Acc=0.7050 | F1=0.6745 | G-Mean=0.5455 | MCC=0.6898
#   [GaussianNB] Iter  6 | Labeled=506 | Acc=0.7060 | F1=0.6761 | G-Mean=0.5502 | MCC=0.6908
#   [GaussianNB] Iter  7 | Labeled=507 | Acc=0.6990 | F1=0.6701 | G-Mean=0.5451 | MCC=0.6835
#   [GaussianNB] Iter  8 | Labeled=508 | Acc=0.6980 | F1=0.6684 | G-Mean=0.5430 | MCC=0.6824
#   [GaussianNB] Iter  9 | Labeled=509 | Acc=0.6970 | F1=0.6672 | G-Mean=0.5415 | MCC=0.6814
#   [GaussianNB] Iter 10 | Labeled=510 | Acc=0.6970 | F1=0.6672 | G-Mean=0.5415 | MCC=0.6814
#
# === Active Learning: Stacking | Original ===
#   [Stacking] Iter  1 | Labeled=501 | Acc=0.8790 | F1=0.8758 | G-Mean=0.8474 | MCC=0.8718
#   [Stacking] Iter  2 | Labeled=502 | Acc=0.8790 | F1=0.8756 | G-Mean=0.8448 | MCC=0.8718
#   [Stacking] Iter  3 | Labeled=503 | Acc=0.8810 | F1=0.8777 | G-Mean=0.8502 | MCC=0.8739
#   [Stacking] Iter  4 | Labeled=504 | Acc=0.8850 | F1=0.8820 | G-Mean=0.8566 | MCC=0.8781
#   [Stacking] Iter  5 | Labeled=505 | Acc=0.8830 | F1=0.8802 | G-Mean=0.8549 | MCC=0.8760
#   [Stacking] Iter  6 | Labeled=506 | Acc=0.8830 | F1=0.8807 | G-Mean=0.8570 | MCC=0.8760
#   [Stacking] Iter  7 | Labeled=507 | Acc=0.8850 | F1=0.8825 | G-Mean=0.8587 | MCC=0.8781
#   [Stacking] Iter  8 | Labeled=508 | Acc=0.8920 | F1=0.8901 | G-Mean=0.8676 | MCC=0.8855
#   [Stacking] Iter  9 | Labeled=509 | Acc=0.8880 | F1=0.8857 | G-Mean=0.8609 | MCC=0.8813
#   [Stacking] Iter 10 | Labeled=510 | Acc=0.8860 | F1=0.8841 | G-Mean=0.8588 | MCC=0.8790
#
# === Active Learning: Hard Voting | Original ===
#   [Hard Voting] Iter  1 | Labeled=501 | Acc=0.8660 | F1=0.8601 | G-Mean=0.8150 | MCC=0.8581
#   [Hard Voting] Iter  2 | Labeled=502 | Acc=0.8660 | F1=0.8603 | G-Mean=0.8152 | MCC=0.8581
#   [Hard Voting] Iter  3 | Labeled=503 | Acc=0.8720 | F1=0.8673 | G-Mean=0.8254 | MCC=0.8644
#   [Hard Voting] Iter  4 | Labeled=504 | Acc=0.8680 | F1=0.8624 | G-Mean=0.8193 | MCC=0.8602
#   [Hard Voting] Iter  5 | Labeled=505 | Acc=0.8690 | F1=0.8641 | G-Mean=0.8211 | MCC=0.8613
#   [Hard Voting] Iter  6 | Labeled=506 | Acc=0.8710 | F1=0.8660 | G-Mean=0.8238 | MCC=0.8634
#   [Hard Voting] Iter  7 | Labeled=507 | Acc=0.8720 | F1=0.8669 | G-Mean=0.8247 | MCC=0.8644
#   [Hard Voting] Iter  8 | Labeled=508 | Acc=0.8720 | F1=0.8671 | G-Mean=0.8264 | MCC=0.8644
#   [Hard Voting] Iter  9 | Labeled=509 | Acc=0.8760 | F1=0.8716 | G-Mean=0.8347 | MCC=0.8686
#   [Hard Voting] Iter 10 | Labeled=510 | Acc=0.8700 | F1=0.8643 | G-Mean=0.8187 | MCC=0.8623
#
# === Active Learning: Soft Voting | Original ===
#   [Soft Voting] Iter  1 | Labeled=501 | Acc=0.8740 | F1=0.8703 | G-Mean=0.8357 | MCC=0.8664
#   [Soft Voting] Iter  2 | Labeled=502 | Acc=0.8710 | F1=0.8667 | G-Mean=0.8324 | MCC=0.8633
#   [Soft Voting] Iter  3 | Labeled=503 | Acc=0.8720 | F1=0.8685 | G-Mean=0.8363 | MCC=0.8643
#   [Soft Voting] Iter  4 | Labeled=504 | Acc=0.8710 | F1=0.8678 | G-Mean=0.8361 | MCC=0.8632
#   [Soft Voting] Iter  5 | Labeled=505 | Acc=0.8720 | F1=0.8687 | G-Mean=0.8366 | MCC=0.8642
#   [Soft Voting] Iter  6 | Labeled=506 | Acc=0.8750 | F1=0.8716 | G-Mean=0.8402 | MCC=0.8674
#   [Soft Voting] Iter  7 | Labeled=507 | Acc=0.8790 | F1=0.8762 | G-Mean=0.8481 | MCC=0.8717
#   [Soft Voting] Iter  8 | Labeled=508 | Acc=0.8790 | F1=0.8760 | G-Mean=0.8479 | MCC=0.8717
#   [Soft Voting] Iter  9 | Labeled=509 | Acc=0.8820 | F1=0.8795 | G-Mean=0.8526 | MCC=0.8749
#   [Soft Voting] Iter 10 | Labeled=510 | Acc=0.8810 | F1=0.8784 | G-Mean=0.8510 | MCC=0.8738
#
# === Active Learning: Weighted Voting | Original ===
#   [Weighted Voting] Iter  1 | Labeled=501 | Acc=0.8740 | F1=0.8705 | G-Mean=0.8362 | MCC=0.8664
#   [Weighted Voting] Iter  2 | Labeled=502 | Acc=0.8710 | F1=0.8674 | G-Mean=0.8347 | MCC=0.8632
#   [Weighted Voting] Iter  3 | Labeled=503 | Acc=0.8750 | F1=0.8718 | G-Mean=0.8394 | MCC=0.8675
#   [Weighted Voting] Iter  4 | Labeled=504 | Acc=0.8760 | F1=0.8727 | G-Mean=0.8399 | MCC=0.8686
#   [Weighted Voting] Iter  5 | Labeled=505 | Acc=0.8770 | F1=0.8738 | G-Mean=0.8429 | MCC=0.8697
#   [Weighted Voting] Iter  6 | Labeled=506 | Acc=0.8760 | F1=0.8725 | G-Mean=0.8401 | MCC=0.8686
#   [Weighted Voting] Iter  7 | Labeled=507 | Acc=0.8770 | F1=0.8734 | G-Mean=0.8409 | MCC=0.8697
#   [Weighted Voting] Iter  8 | Labeled=508 | Acc=0.8820 | F1=0.8798 | G-Mean=0.8518 | MCC=0.8749
#   [Weighted Voting] Iter  9 | Labeled=509 | Acc=0.8820 | F1=0.8796 | G-Mean=0.8492 | MCC=0.8749
#   [Weighted Voting] Iter 10 | Labeled=510 | Acc=0.8840 | F1=0.8818 | G-Mean=0.8531 | MCC=0.8770
#
# === Active Learning: Adding (Avg Probabilities) | Original ===
#   [Adding (Avg Probabilities)] Iter  1 | Labeled=501 | Acc=0.8740 | F1=0.8703 | G-Mean=0.8357 | MCC=0.8664
#   [Adding (Avg Probabilities)] Iter  2 | Labeled=502 | Acc=0.8710 | F1=0.8667 | G-Mean=0.8324 | MCC=0.8633
#   [Adding (Avg Probabilities)] Iter  3 | Labeled=503 | Acc=0.8720 | F1=0.8685 | G-Mean=0.8363 | MCC=0.8643
#   [Adding (Avg Probabilities)] Iter  4 | Labeled=504 | Acc=0.8710 | F1=0.8678 | G-Mean=0.8361 | MCC=0.8632
#   [Adding (Avg Probabilities)] Iter  5 | Labeled=505 | Acc=0.8720 | F1=0.8687 | G-Mean=0.8366 | MCC=0.8642
#   [Adding (Avg Probabilities)] Iter  6 | Labeled=506 | Acc=0.8750 | F1=0.8716 | G-Mean=0.8402 | MCC=0.8674
#   [Adding (Avg Probabilities)] Iter  7 | Labeled=507 | Acc=0.8790 | F1=0.8763 | G-Mean=0.8481 | MCC=0.8717
#   [Adding (Avg Probabilities)] Iter  8 | Labeled=508 | Acc=0.8790 | F1=0.8760 | G-Mean=0.8479 | MCC=0.8717
#   [Adding (Avg Probabilities)] Iter  9 | Labeled=509 | Acc=0.8820 | F1=0.8795 | G-Mean=0.8526 | MCC=0.8749
#   [Adding (Avg Probabilities)] Iter 10 | Labeled=510 | Acc=0.8810 | F1=0.8784 | G-Mean=0.8510 | MCC=0.8738
#
# === Active Learning: Logistic Regression | Random Undersampling ===
#   [Logistic Regression] Iter  1 | Labeled=501 | Acc=0.8551 | F1=0.8534 | G-Mean=0.8497 | MCC=0.8471
#   [Logistic Regression] Iter  2 | Labeled=502 | Acc=0.8517 | F1=0.8500 | G-Mean=0.8463 | MCC=0.8434
#   [Logistic Regression] Iter  3 | Labeled=503 | Acc=0.8534 | F1=0.8520 | G-Mean=0.8485 | MCC=0.8452
#   [Logistic Regression] Iter  4 | Labeled=504 | Acc=0.8586 | F1=0.8573 | G-Mean=0.8532 | MCC=0.8508
#   [Logistic Regression] Iter  5 | Labeled=505 | Acc=0.8534 | F1=0.8522 | G-Mean=0.8485 | MCC=0.8452
#   [Logistic Regression] Iter  6 | Labeled=506 | Acc=0.8482 | F1=0.8467 | G-Mean=0.8430 | MCC=0.8397
#   [Logistic Regression] Iter  7 | Labeled=507 | Acc=0.8534 | F1=0.8520 | G-Mean=0.8483 | MCC=0.8452
#   [Logistic Regression] Iter  8 | Labeled=508 | Acc=0.8499 | F1=0.8483 | G-Mean=0.8442 | MCC=0.8416
#   [Logistic Regression] Iter  9 | Labeled=509 | Acc=0.8534 | F1=0.8519 | G-Mean=0.8479 | MCC=0.8453
#   [Logistic Regression] Iter 10 | Labeled=510 | Acc=0.8534 | F1=0.8518 | G-Mean=0.8482 | MCC=0.8452
#
# === Active Learning: SVM | Random Undersampling ===
#   [SVM] Iter  1 | Labeled=501 | Acc=0.2373 | F1=0.1591 | G-Mean=0.2772 | MCC=0.2089
#   [SVM] Iter  2 | Labeled=502 | Acc=0.2373 | F1=0.1589 | G-Mean=0.2772 | MCC=0.2089
#   [SVM] Iter  3 | Labeled=503 | Acc=0.2356 | F1=0.1538 | G-Mean=0.2526 | MCC=0.2071
#   [SVM] Iter  4 | Labeled=504 | Acc=0.2356 | F1=0.1538 | G-Mean=0.2526 | MCC=0.2071
#   [SVM] Iter  5 | Labeled=505 | Acc=0.2339 | F1=0.1536 | G-Mean=0.2517 | MCC=0.2042
#   [SVM] Iter  6 | Labeled=506 | Acc=0.2339 | F1=0.1536 | G-Mean=0.2517 | MCC=0.2042
#   [SVM] Iter  7 | Labeled=507 | Acc=0.2339 | F1=0.1536 | G-Mean=0.2517 | MCC=0.2042
#   [SVM] Iter  8 | Labeled=508 | Acc=0.2391 | F1=0.1587 | G-Mean=0.2584 | MCC=0.2100
#   [SVM] Iter  9 | Labeled=509 | Acc=0.2391 | F1=0.1579 | G-Mean=0.2584 | MCC=0.2096
#   [SVM] Iter 10 | Labeled=510 | Acc=0.2391 | F1=0.1633 | G-Mean=0.2198 | MCC=0.2078
#
# === Active Learning: Naive Bayes | Random Undersampling ===
#   [Naive Bayes] Iter  1 | Labeled=501 | Acc=0.6422 | F1=0.6113 | G-Mean=0.5631 | MCC=0.6266
#   [Naive Bayes] Iter  2 | Labeled=502 | Acc=0.6440 | F1=0.6140 | G-Mean=0.5664 | MCC=0.6284
#   [Naive Bayes] Iter  3 | Labeled=503 | Acc=0.6440 | F1=0.6140 | G-Mean=0.5664 | MCC=0.6284
#   [Naive Bayes] Iter  4 | Labeled=504 | Acc=0.6440 | F1=0.6140 | G-Mean=0.5664 | MCC=0.6284
#   [Naive Bayes] Iter  5 | Labeled=505 | Acc=0.6440 | F1=0.6140 | G-Mean=0.5664 | MCC=0.6284
#   [Naive Bayes] Iter  6 | Labeled=506 | Acc=0.6440 | F1=0.6140 | G-Mean=0.5664 | MCC=0.6284
#   [Naive Bayes] Iter  7 | Labeled=507 | Acc=0.6440 | F1=0.6140 | G-Mean=0.5664 | MCC=0.6284
#   [Naive Bayes] Iter  8 | Labeled=508 | Acc=0.6422 | F1=0.6124 | G-Mean=0.5654 | MCC=0.6265
#   [Naive Bayes] Iter  9 | Labeled=509 | Acc=0.6440 | F1=0.6139 | G-Mean=0.5667 | MCC=0.6283
#   [Naive Bayes] Iter 10 | Labeled=510 | Acc=0.6422 | F1=0.6111 | G-Mean=0.5619 | MCC=0.6265
#
# === Active Learning: K-Nearest Neighbors | Random Undersampling ===
#   [K-Nearest Neighbors] Iter  1 | Labeled=501 | Acc=0.2373 | F1=0.2214 | G-Mean=0.1857 | MCC=0.1948
#   [K-Nearest Neighbors] Iter  2 | Labeled=502 | Acc=0.2373 | F1=0.2214 | G-Mean=0.1857 | MCC=0.1948
#   [K-Nearest Neighbors] Iter  3 | Labeled=503 | Acc=0.2373 | F1=0.2216 | G-Mean=0.1857 | MCC=0.1948
#   [K-Nearest Neighbors] Iter  4 | Labeled=504 | Acc=0.2356 | F1=0.2191 | G-Mean=0.1828 | MCC=0.1929
#   [K-Nearest Neighbors] Iter  5 | Labeled=505 | Acc=0.2339 | F1=0.2184 | G-Mean=0.1812 | MCC=0.1911
#   [K-Nearest Neighbors] Iter  6 | Labeled=506 | Acc=0.2339 | F1=0.2183 | G-Mean=0.1812 | MCC=0.1911
#   [K-Nearest Neighbors] Iter  7 | Labeled=507 | Acc=0.2339 | F1=0.2182 | G-Mean=0.1812 | MCC=0.1910
#   [K-Nearest Neighbors] Iter  8 | Labeled=508 | Acc=0.2304 | F1=0.2139 | G-Mean=0.1755 | MCC=0.1873
#   [K-Nearest Neighbors] Iter  9 | Labeled=509 | Acc=0.2304 | F1=0.2139 | G-Mean=0.1755 | MCC=0.1873
#   [K-Nearest Neighbors] Iter 10 | Labeled=510 | Acc=0.2304 | F1=0.2143 | G-Mean=0.1755 | MCC=0.1876
#
# === Active Learning: Decision Tree | Random Undersampling ===
#   [Decision Tree] Iter  1 | Labeled=501 | Acc=0.7574 | F1=0.7564 | G-Mean=0.7365 | MCC=0.7435
#   [Decision Tree] Iter  2 | Labeled=502 | Acc=0.7522 | F1=0.7529 | G-Mean=0.7351 | MCC=0.7377
#   [Decision Tree] Iter  3 | Labeled=503 | Acc=0.7382 | F1=0.7385 | G-Mean=0.7228 | MCC=0.7230
#   [Decision Tree] Iter  4 | Labeled=504 | Acc=0.7417 | F1=0.7414 | G-Mean=0.7206 | MCC=0.7269
#   [Decision Tree] Iter  5 | Labeled=505 | Acc=0.7382 | F1=0.7375 | G-Mean=0.7194 | MCC=0.7232
#   [Decision Tree] Iter  6 | Labeled=506 | Acc=0.7435 | F1=0.7434 | G-Mean=0.7230 | MCC=0.7287
#   [Decision Tree] Iter  7 | Labeled=507 | Acc=0.7347 | F1=0.7341 | G-Mean=0.7163 | MCC=0.7195
#   [Decision Tree] Iter  8 | Labeled=508 | Acc=0.7452 | F1=0.7435 | G-Mean=0.7242 | MCC=0.7305
#   [Decision Tree] Iter  9 | Labeled=509 | Acc=0.7452 | F1=0.7449 | G-Mean=0.7278 | MCC=0.7304
#   [Decision Tree] Iter 10 | Labeled=510 | Acc=0.7417 | F1=0.7408 | G-Mean=0.7242 | MCC=0.7267
#
# === Active Learning: Random Forest | Random Undersampling ===
#   [Random Forest] Iter  1 | Labeled=501 | Acc=0.8255 | F1=0.8211 | G-Mean=0.8122 | MCC=0.8160
#   [Random Forest] Iter  2 | Labeled=502 | Acc=0.8342 | F1=0.8307 | G-Mean=0.8236 | MCC=0.8252
#   [Random Forest] Iter  3 | Labeled=503 | Acc=0.8220 | F1=0.8181 | G-Mean=0.8099 | MCC=0.8122
#   [Random Forest] Iter  4 | Labeled=504 | Acc=0.8237 | F1=0.8195 | G-Mean=0.8119 | MCC=0.8141
#   [Random Forest] Iter  5 | Labeled=505 | Acc=0.8290 | F1=0.8255 | G-Mean=0.8169 | MCC=0.8194
#   [Random Forest] Iter  6 | Labeled=506 | Acc=0.8272 | F1=0.8227 | G-Mean=0.8137 | MCC=0.8178
#   [Random Forest] Iter  7 | Labeled=507 | Acc=0.8272 | F1=0.8234 | G-Mean=0.8153 | MCC=0.8176
#   [Random Forest] Iter  8 | Labeled=508 | Acc=0.8360 | F1=0.8317 | G-Mean=0.8223 | MCC=0.8270
#   [Random Forest] Iter  9 | Labeled=509 | Acc=0.8360 | F1=0.8314 | G-Mean=0.8219 | MCC=0.8270
#   [Random Forest] Iter 10 | Labeled=510 | Acc=0.8429 | F1=0.8399 | G-Mean=0.8322 | MCC=0.8343
#
# === Active Learning: Gradient Boosting | Random Undersampling ===
#   [Gradient Boosting] Iter  1 | Labeled=501 | Acc=0.8220 | F1=0.8168 | G-Mean=0.8078 | MCC=0.8123
#   [Gradient Boosting] Iter  2 | Labeled=502 | Acc=0.8237 | F1=0.8190 | G-Mean=0.8105 | MCC=0.8143
#   [Gradient Boosting] Iter  3 | Labeled=503 | Acc=0.8237 | F1=0.8190 | G-Mean=0.8103 | MCC=0.8142
#   [Gradient Boosting] Iter  4 | Labeled=504 | Acc=0.8307 | F1=0.8264 | G-Mean=0.8183 | MCC=0.8216
#   [Gradient Boosting] Iter  5 | Labeled=505 | Acc=0.8237 | F1=0.8193 | G-Mean=0.8107 | MCC=0.8143
#   [Gradient Boosting] Iter  6 | Labeled=506 | Acc=0.8272 | F1=0.8238 | G-Mean=0.8160 | MCC=0.8180
#   [Gradient Boosting] Iter  7 | Labeled=507 | Acc=0.8237 | F1=0.8200 | G-Mean=0.8125 | MCC=0.8142
#   [Gradient Boosting] Iter  8 | Labeled=508 | Acc=0.8272 | F1=0.8228 | G-Mean=0.8143 | MCC=0.8180
#   [Gradient Boosting] Iter  9 | Labeled=509 | Acc=0.8342 | F1=0.8293 | G-Mean=0.8199 | MCC=0.8254
#   [Gradient Boosting] Iter 10 | Labeled=510 | Acc=0.8272 | F1=0.8234 | G-Mean=0.8160 | MCC=0.8180
#
# === Active Learning: XGBoost | Random Undersampling ===
#   [XGBoost] Iter  1 | Labeled=501 | Acc=0.8551 | F1=0.8524 | G-Mean=0.8459 | MCC=0.8473
#   [XGBoost] Iter  2 | Labeled=502 | Acc=0.8534 | F1=0.8511 | G-Mean=0.8457 | MCC=0.8453
#   [XGBoost] Iter  3 | Labeled=503 | Acc=0.8534 | F1=0.8504 | G-Mean=0.8435 | MCC=0.8455
#   [XGBoost] Iter  4 | Labeled=504 | Acc=0.8517 | F1=0.8484 | G-Mean=0.8411 | MCC=0.8436
#   [XGBoost] Iter  5 | Labeled=505 | Acc=0.8499 | F1=0.8469 | G-Mean=0.8400 | MCC=0.8417
#   [XGBoost] Iter  6 | Labeled=506 | Acc=0.8464 | F1=0.8434 | G-Mean=0.8368 | MCC=0.8380
#   [XGBoost] Iter  7 | Labeled=507 | Acc=0.8499 | F1=0.8476 | G-Mean=0.8417 | MCC=0.8416
#   [XGBoost] Iter  8 | Labeled=508 | Acc=0.8517 | F1=0.8486 | G-Mean=0.8416 | MCC=0.8435
#   [XGBoost] Iter  9 | Labeled=509 | Acc=0.8517 | F1=0.8488 | G-Mean=0.8420 | MCC=0.8435
#   [XGBoost] Iter 10 | Labeled=510 | Acc=0.8517 | F1=0.8499 | G-Mean=0.8445 | MCC=0.8434
#
# === Active Learning: LightGBM | Random Undersampling ===
#   [LightGBM] Iter  1 | Labeled=501 | Acc=0.8674 | F1=0.8648 | G-Mean=0.8597 | MCC=0.8602
#   [LightGBM] Iter  2 | Labeled=502 | Acc=0.8656 | F1=0.8632 | G-Mean=0.8584 | MCC=0.8582
#   [LightGBM] Iter  3 | Labeled=503 | Acc=0.8709 | F1=0.8681 | G-Mean=0.8633 | MCC=0.8638
#   [LightGBM] Iter  4 | Labeled=504 | Acc=0.8674 | F1=0.8642 | G-Mean=0.8582 | MCC=0.8602
#   [LightGBM] Iter  5 | Labeled=505 | Acc=0.8621 | F1=0.8587 | G-Mean=0.8525 | MCC=0.8547
#   [LightGBM] Iter  6 | Labeled=506 | Acc=0.8674 | F1=0.8646 | G-Mean=0.8597 | MCC=0.8601
#   [LightGBM] Iter  7 | Labeled=507 | Acc=0.8656 | F1=0.8627 | G-Mean=0.8576 | MCC=0.8583
#   [LightGBM] Iter  8 | Labeled=508 | Acc=0.8639 | F1=0.8608 | G-Mean=0.8555 | MCC=0.8565
#   [LightGBM] Iter  9 | Labeled=509 | Acc=0.8586 | F1=0.8553 | G-Mean=0.8500 | MCC=0.8510
#   [LightGBM] Iter 10 | Labeled=510 | Acc=0.8586 | F1=0.8556 | G-Mean=0.8505 | MCC=0.8509
#
# === Active Learning: CatBoost | Random Undersampling ===
#   [CatBoost] Iter  1 | Labeled=501 | Acc=0.8551 | F1=0.8524 | G-Mean=0.8469 | MCC=0.8471
#   [CatBoost] Iter  2 | Labeled=502 | Acc=0.8517 | F1=0.8494 | G-Mean=0.8442 | MCC=0.8433
#   [CatBoost] Iter  3 | Labeled=503 | Acc=0.8551 | F1=0.8534 | G-Mean=0.8487 | MCC=0.8470
#   [CatBoost] Iter  4 | Labeled=504 | Acc=0.8551 | F1=0.8533 | G-Mean=0.8488 | MCC=0.8469
#   [CatBoost] Iter  5 | Labeled=505 | Acc=0.8534 | F1=0.8517 | G-Mean=0.8468 | MCC=0.8450
#   [CatBoost] Iter  6 | Labeled=506 | Acc=0.8551 | F1=0.8534 | G-Mean=0.8484 | MCC=0.8469
#   [CatBoost] Iter  7 | Labeled=507 | Acc=0.8551 | F1=0.8530 | G-Mean=0.8480 | MCC=0.8469
#   [CatBoost] Iter  8 | Labeled=508 | Acc=0.8499 | F1=0.8479 | G-Mean=0.8429 | MCC=0.8413
#   [CatBoost] Iter  9 | Labeled=509 | Acc=0.8569 | F1=0.8552 | G-Mean=0.8505 | MCC=0.8487
#   [CatBoost] Iter 10 | Labeled=510 | Acc=0.8586 | F1=0.8568 | G-Mean=0.8520 | MCC=0.8506
#
# === Active Learning: AdaBoost | Random Undersampling ===
#   [AdaBoost] Iter  1 | Labeled=501 | Acc=0.1850 | F1=0.1079 | G-Mean=0.1785 | MCC=0.1452
#   [AdaBoost] Iter  2 | Labeled=502 | Acc=0.1972 | F1=0.1371 | G-Mean=0.2016 | MCC=0.1586
#   [AdaBoost] Iter  3 | Labeled=503 | Acc=0.2129 | F1=0.1166 | G-Mean=0.1935 | MCC=0.1860
#   [AdaBoost] Iter  4 | Labeled=504 | Acc=0.2234 | F1=0.1272 | G-Mean=0.4241 | MCC=0.1949
#   [AdaBoost] Iter  5 | Labeled=505 | Acc=0.2182 | F1=0.1129 | G-Mean=0.5160 | MCC=0.1948
#   [AdaBoost] Iter  6 | Labeled=506 | Acc=0.2880 | F1=0.1958 | G-Mean=0.5299 | MCC=0.2617
#   [AdaBoost] Iter  7 | Labeled=507 | Acc=0.2443 | F1=0.1931 | G-Mean=0.3571 | MCC=0.2118
#   [AdaBoost] Iter  8 | Labeled=508 | Acc=0.1449 | F1=0.0636 | G-Mean=0.3662 | MCC=0.1143
#   [AdaBoost] Iter  9 | Labeled=509 | Acc=0.1658 | F1=0.0908 | G-Mean=0.2303 | MCC=0.1294
#   [AdaBoost] Iter 10 | Labeled=510 | Acc=0.2897 | F1=0.1957 | G-Mean=0.2715 | MCC=0.2632
#
# === Active Learning: Extra Trees | Random Undersampling ===
#   [Extra Trees] Iter  1 | Labeled=501 | Acc=0.8080 | F1=0.8011 | G-Mean=0.7910 | MCC=0.7978
#   [Extra Trees] Iter  2 | Labeled=502 | Acc=0.8063 | F1=0.7992 | G-Mean=0.7884 | MCC=0.7961
#   [Extra Trees] Iter  3 | Labeled=503 | Acc=0.8202 | F1=0.8163 | G-Mean=0.8086 | MCC=0.8106
#   [Extra Trees] Iter  4 | Labeled=504 | Acc=0.8010 | F1=0.7953 | G-Mean=0.7865 | MCC=0.7904
#   [Extra Trees] Iter  5 | Labeled=505 | Acc=0.8080 | F1=0.8022 | G-Mean=0.7939 | MCC=0.7977
#   [Extra Trees] Iter  6 | Labeled=506 | Acc=0.8063 | F1=0.8004 | G-Mean=0.7918 | MCC=0.7959
#   [Extra Trees] Iter  7 | Labeled=507 | Acc=0.8010 | F1=0.7934 | G-Mean=0.7821 | MCC=0.7904
#   [Extra Trees] Iter  8 | Labeled=508 | Acc=0.8063 | F1=0.7989 | G-Mean=0.7888 | MCC=0.7960
#   [Extra Trees] Iter  9 | Labeled=509 | Acc=0.8028 | F1=0.7963 | G-Mean=0.7863 | MCC=0.7921
#   [Extra Trees] Iter 10 | Labeled=510 | Acc=0.7976 | F1=0.7907 | G-Mean=0.7802 | MCC=0.7867
#
# === Active Learning: Ridge Classifier | Random Undersampling ===
#   [Ridge Classifier] Iter  1 | Labeled=501 | Acc=0.6056 | F1=0.5429 | G-Mean=0.4802 | MCC=0.5910
#   [Ridge Classifier] Iter  2 | Labeled=502 | Acc=0.6038 | F1=0.5415 | G-Mean=0.4788 | MCC=0.5891
#   [Ridge Classifier] Iter  3 | Labeled=503 | Acc=0.6091 | F1=0.5510 | G-Mean=0.5108 | MCC=0.5945
#   [Ridge Classifier] Iter  4 | Labeled=504 | Acc=0.6108 | F1=0.5523 | G-Mean=0.5118 | MCC=0.5964
#   [Ridge Classifier] Iter  5 | Labeled=505 | Acc=0.6091 | F1=0.5494 | G-Mean=0.5064 | MCC=0.5945
#   [Ridge Classifier] Iter  6 | Labeled=506 | Acc=0.6091 | F1=0.5510 | G-Mean=0.5107 | MCC=0.5944
#   [Ridge Classifier] Iter  7 | Labeled=507 | Acc=0.6091 | F1=0.5510 | G-Mean=0.5107 | MCC=0.5944
#   [Ridge Classifier] Iter  8 | Labeled=508 | Acc=0.6126 | F1=0.5570 | G-Mean=0.5232 | MCC=0.5977
#   [Ridge Classifier] Iter  9 | Labeled=509 | Acc=0.6143 | F1=0.5571 | G-Mean=0.5193 | MCC=0.5996
#   [Ridge Classifier] Iter 10 | Labeled=510 | Acc=0.6161 | F1=0.5587 | G-Mean=0.5224 | MCC=0.6014
#
# === Active Learning: Perceptron | Random Undersampling ===
#   [Perceptron] Iter  1 | Labeled=501 | Acc=0.1693 | F1=0.0917 | G-Mean=0.2422 | MCC=0.1330
#   [Perceptron] Iter  2 | Labeled=502 | Acc=0.1658 | F1=0.0926 | G-Mean=0.3294 | MCC=0.1282
#   [Perceptron] Iter  3 | Labeled=503 | Acc=0.2077 | F1=0.1191 | G-Mean=0.4253 | MCC=0.1776
#   [Perceptron] Iter  4 | Labeled=504 | Acc=0.0925 | F1=0.0504 | G-Mean=0.3096 | MCC=0.0469
#   [Perceptron] Iter  5 | Labeled=505 | Acc=0.2007 | F1=0.1392 | G-Mean=0.2451 | MCC=0.1601
#   [Perceptron] Iter  6 | Labeled=506 | Acc=0.2251 | F1=0.1296 | G-Mean=0.4896 | MCC=0.1979
#   [Perceptron] Iter  7 | Labeled=507 | Acc=0.1501 | F1=0.1032 | G-Mean=0.3215 | MCC=0.1142
#   [Perceptron] Iter  8 | Labeled=508 | Acc=0.2024 | F1=0.1098 | G-Mean=0.4310 | MCC=0.1656
#   [Perceptron] Iter  9 | Labeled=509 | Acc=0.0698 | F1=0.0318 | G-Mean=0.1525 | MCC=0.0204
#   [Perceptron] Iter 10 | Labeled=510 | Acc=0.1623 | F1=0.1233 | G-Mean=0.1954 | MCC=0.1183
#
# === Active Learning: Bagging Classifier | Random Undersampling ===
#   [Bagging Classifier] Iter  1 | Labeled=501 | Acc=0.8115 | F1=0.8063 | G-Mean=0.7951 | MCC=0.8010
#   [Bagging Classifier] Iter  2 | Labeled=502 | Acc=0.8080 | F1=0.8032 | G-Mean=0.7946 | MCC=0.7973
#   [Bagging Classifier] Iter  3 | Labeled=503 | Acc=0.7923 | F1=0.7869 | G-Mean=0.7752 | MCC=0.7807
#   [Bagging Classifier] Iter  4 | Labeled=504 | Acc=0.7923 | F1=0.7860 | G-Mean=0.7723 | MCC=0.7807
#   [Bagging Classifier] Iter  5 | Labeled=505 | Acc=0.7976 | F1=0.7921 | G-Mean=0.7798 | MCC=0.7863
#   [Bagging Classifier] Iter  6 | Labeled=506 | Acc=0.7731 | F1=0.7668 | G-Mean=0.7501 | MCC=0.7606
#   [Bagging Classifier] Iter  7 | Labeled=507 | Acc=0.7976 | F1=0.7902 | G-Mean=0.7742 | MCC=0.7865
#   [Bagging Classifier] Iter  8 | Labeled=508 | Acc=0.8045 | F1=0.7975 | G-Mean=0.7827 | MCC=0.7937
#   [Bagging Classifier] Iter  9 | Labeled=509 | Acc=0.8028 | F1=0.7956 | G-Mean=0.7809 | MCC=0.7918
#   [Bagging Classifier] Iter 10 | Labeled=510 | Acc=0.8133 | F1=0.8101 | G-Mean=0.8011 | MCC=0.8026
#
# === Active Learning: GaussianNB | Random Undersampling ===
#   [GaussianNB] Iter  1 | Labeled=501 | Acc=0.6422 | F1=0.6113 | G-Mean=0.5631 | MCC=0.6266
#   [GaussianNB] Iter  2 | Labeled=502 | Acc=0.6440 | F1=0.6140 | G-Mean=0.5664 | MCC=0.6284
#   [GaussianNB] Iter  3 | Labeled=503 | Acc=0.6440 | F1=0.6140 | G-Mean=0.5664 | MCC=0.6284
#   [GaussianNB] Iter  4 | Labeled=504 | Acc=0.6440 | F1=0.6140 | G-Mean=0.5664 | MCC=0.6284
#   [GaussianNB] Iter  5 | Labeled=505 | Acc=0.6440 | F1=0.6140 | G-Mean=0.5664 | MCC=0.6284
#   [GaussianNB] Iter  6 | Labeled=506 | Acc=0.6440 | F1=0.6140 | G-Mean=0.5664 | MCC=0.6284
#   [GaussianNB] Iter  7 | Labeled=507 | Acc=0.6440 | F1=0.6140 | G-Mean=0.5664 | MCC=0.6284
#   [GaussianNB] Iter  8 | Labeled=508 | Acc=0.6422 | F1=0.6124 | G-Mean=0.5654 | MCC=0.6265
#   [GaussianNB] Iter  9 | Labeled=509 | Acc=0.6440 | F1=0.6139 | G-Mean=0.5667 | MCC=0.6283
#   [GaussianNB] Iter 10 | Labeled=510 | Acc=0.6422 | F1=0.6111 | G-Mean=0.5619 | MCC=0.6265
#
# === Active Learning: Stacking | Random Undersampling ===
#   [Stacking] Iter  1 | Labeled=501 | Acc=0.8691 | F1=0.8677 | G-Mean=0.8635 | MCC=0.8620
#   [Stacking] Iter  2 | Labeled=502 | Acc=0.8656 | F1=0.8637 | G-Mean=0.8592 | MCC=0.8583
#   [Stacking] Iter  3 | Labeled=503 | Acc=0.8726 | F1=0.8705 | G-Mean=0.8653 | MCC=0.8657
#   [Stacking] Iter  4 | Labeled=504 | Acc=0.8639 | F1=0.8623 | G-Mean=0.8576 | MCC=0.8564
#   [Stacking] Iter  5 | Labeled=505 | Acc=0.8674 | F1=0.8657 | G-Mean=0.8610 | MCC=0.8601
#   [Stacking] Iter  6 | Labeled=506 | Acc=0.8621 | F1=0.8607 | G-Mean=0.8562 | MCC=0.8546
#   [Stacking] Iter  7 | Labeled=507 | Acc=0.8691 | F1=0.8665 | G-Mean=0.8604 | MCC=0.8622
#   [Stacking] Iter  8 | Labeled=508 | Acc=0.8761 | F1=0.8749 | G-Mean=0.8700 | MCC=0.8693
#   [Stacking] Iter  9 | Labeled=509 | Acc=0.8656 | F1=0.8640 | G-Mean=0.8596 | MCC=0.8582
#   [Stacking] Iter 10 | Labeled=510 | Acc=0.8691 | F1=0.8671 | G-Mean=0.8621 | MCC=0.8620
#
# === Active Learning: Hard Voting | Random Undersampling ===
#   [Hard Voting] Iter  1 | Labeled=501 | Acc=0.8604 | F1=0.8574 | G-Mean=0.8519 | MCC=0.8528
#   [Hard Voting] Iter  2 | Labeled=502 | Acc=0.8569 | F1=0.8540 | G-Mean=0.8484 | MCC=0.8491
#   [Hard Voting] Iter  3 | Labeled=503 | Acc=0.8656 | F1=0.8629 | G-Mean=0.8581 | MCC=0.8582
#   [Hard Voting] Iter  4 | Labeled=504 | Acc=0.8639 | F1=0.8607 | G-Mean=0.8551 | MCC=0.8565
#   [Hard Voting] Iter  5 | Labeled=505 | Acc=0.8656 | F1=0.8624 | G-Mean=0.8566 | MCC=0.8583
#   [Hard Voting] Iter  6 | Labeled=506 | Acc=0.8586 | F1=0.8552 | G-Mean=0.8493 | MCC=0.8509
#   [Hard Voting] Iter  7 | Labeled=507 | Acc=0.8656 | F1=0.8626 | G-Mean=0.8572 | MCC=0.8583
#   [Hard Voting] Iter  8 | Labeled=508 | Acc=0.8586 | F1=0.8560 | G-Mean=0.8508 | MCC=0.8509
#   [Hard Voting] Iter  9 | Labeled=509 | Acc=0.8639 | F1=0.8618 | G-Mean=0.8567 | MCC=0.8564
#   [Hard Voting] Iter 10 | Labeled=510 | Acc=0.8674 | F1=0.8651 | G-Mean=0.8605 | MCC=0.8601
#
# === Active Learning: Soft Voting | Random Undersampling ===
#   [Soft Voting] Iter  1 | Labeled=501 | Acc=0.8709 | F1=0.8682 | G-Mean=0.8630 | MCC=0.8638
#   [Soft Voting] Iter  2 | Labeled=502 | Acc=0.8639 | F1=0.8607 | G-Mean=0.8552 | MCC=0.8565
#   [Soft Voting] Iter  3 | Labeled=503 | Acc=0.8639 | F1=0.8607 | G-Mean=0.8549 | MCC=0.8566
#   [Soft Voting] Iter  4 | Labeled=504 | Acc=0.8674 | F1=0.8634 | G-Mean=0.8567 | MCC=0.8603
#   [Soft Voting] Iter  5 | Labeled=505 | Acc=0.8726 | F1=0.8691 | G-Mean=0.8627 | MCC=0.8658
#   [Soft Voting] Iter  6 | Labeled=506 | Acc=0.8726 | F1=0.8694 | G-Mean=0.8635 | MCC=0.8658
#   [Soft Voting] Iter  7 | Labeled=507 | Acc=0.8691 | F1=0.8658 | G-Mean=0.8601 | MCC=0.8620
#   [Soft Voting] Iter  8 | Labeled=508 | Acc=0.8656 | F1=0.8626 | G-Mean=0.8563 | MCC=0.8583
#   [Soft Voting] Iter  9 | Labeled=509 | Acc=0.8726 | F1=0.8698 | G-Mean=0.8641 | MCC=0.8656
#   [Soft Voting] Iter 10 | Labeled=510 | Acc=0.8639 | F1=0.8603 | G-Mean=0.8538 | MCC=0.8564
#
# === Active Learning: Weighted Voting | Random Undersampling ===
#   [Weighted Voting] Iter  1 | Labeled=501 | Acc=0.8691 | F1=0.8660 | G-Mean=0.8599 | MCC=0.8621
#   [Weighted Voting] Iter  2 | Labeled=502 | Acc=0.8674 | F1=0.8635 | G-Mean=0.8568 | MCC=0.8603
#   [Weighted Voting] Iter  3 | Labeled=503 | Acc=0.8691 | F1=0.8652 | G-Mean=0.8583 | MCC=0.8622
#   [Weighted Voting] Iter  4 | Labeled=504 | Acc=0.8674 | F1=0.8630 | G-Mean=0.8553 | MCC=0.8604
#   [Weighted Voting] Iter  5 | Labeled=505 | Acc=0.8639 | F1=0.8601 | G-Mean=0.8532 | MCC=0.8566
#   [Weighted Voting] Iter  6 | Labeled=506 | Acc=0.8726 | F1=0.8693 | G-Mean=0.8628 | MCC=0.8658
#   [Weighted Voting] Iter  7 | Labeled=507 | Acc=0.8639 | F1=0.8604 | G-Mean=0.8544 | MCC=0.8565
#   [Weighted Voting] Iter  8 | Labeled=508 | Acc=0.8656 | F1=0.8628 | G-Mean=0.8572 | MCC=0.8583
#   [Weighted Voting] Iter  9 | Labeled=509 | Acc=0.8674 | F1=0.8644 | G-Mean=0.8588 | MCC=0.8601
#   [Weighted Voting] Iter 10 | Labeled=510 | Acc=0.8726 | F1=0.8706 | G-Mean=0.8667 | MCC=0.8656
#
# === Active Learning: Adding (Avg Probabilities) | Random Undersampling ===
#   [Adding (Avg Probabilities)] Iter  1 | Labeled=501 | Acc=0.8709 | F1=0.8682 | G-Mean=0.8630 | MCC=0.8638
#   [Adding (Avg Probabilities)] Iter  2 | Labeled=502 | Acc=0.8639 | F1=0.8607 | G-Mean=0.8552 | MCC=0.8565
#   [Adding (Avg Probabilities)] Iter  3 | Labeled=503 | Acc=0.8621 | F1=0.8589 | G-Mean=0.8528 | MCC=0.8547
#   [Adding (Avg Probabilities)] Iter  4 | Labeled=504 | Acc=0.8674 | F1=0.8634 | G-Mean=0.8567 | MCC=0.8603
#   [Adding (Avg Probabilities)] Iter  5 | Labeled=505 | Acc=0.8726 | F1=0.8691 | G-Mean=0.8627 | MCC=0.8658
#   [Adding (Avg Probabilities)] Iter  6 | Labeled=506 | Acc=0.8726 | F1=0.8694 | G-Mean=0.8635 | MCC=0.8658
#   [Adding (Avg Probabilities)] Iter  7 | Labeled=507 | Acc=0.8691 | F1=0.8658 | G-Mean=0.8601 | MCC=0.8620
#   [Adding (Avg Probabilities)] Iter  8 | Labeled=508 | Acc=0.8656 | F1=0.8626 | G-Mean=0.8563 | MCC=0.8583
#   [Adding (Avg Probabilities)] Iter  9 | Labeled=509 | Acc=0.8726 | F1=0.8698 | G-Mean=0.8641 | MCC=0.8656
#   [Adding (Avg Probabilities)] Iter 10 | Labeled=510 | Acc=0.8639 | F1=0.8604 | G-Mean=0.8538 | MCC=0.8564
#
# === Active Learning: Logistic Regression | Random Oversampling ===
#   [Logistic Regression] Iter  1 | Labeled=501 | Acc=0.8368 | F1=0.8377 | G-Mean=0.8330 | MCC=0.8276
#   [Logistic Regression] Iter  2 | Labeled=502 | Acc=0.8395 | F1=0.8404 | G-Mean=0.8362 | MCC=0.8304
#   [Logistic Regression] Iter  3 | Labeled=503 | Acc=0.8436 | F1=0.8445 | G-Mean=0.8401 | MCC=0.8348
#   [Logistic Regression] Iter  4 | Labeled=504 | Acc=0.8381 | F1=0.8390 | G-Mean=0.8346 | MCC=0.8290
#   [Logistic Regression] Iter  5 | Labeled=505 | Acc=0.8347 | F1=0.8355 | G-Mean=0.8306 | MCC=0.8254
#   [Logistic Regression] Iter  6 | Labeled=506 | Acc=0.8388 | F1=0.8392 | G-Mean=0.8342 | MCC=0.8297
#   [Logistic Regression] Iter  7 | Labeled=507 | Acc=0.8368 | F1=0.8372 | G-Mean=0.8323 | MCC=0.8276
#   [Logistic Regression] Iter  8 | Labeled=508 | Acc=0.8306 | F1=0.8315 | G-Mean=0.8263 | MCC=0.8210
#   [Logistic Regression] Iter  9 | Labeled=509 | Acc=0.8416 | F1=0.8423 | G-Mean=0.8370 | MCC=0.8326
#   [Logistic Regression] Iter 10 | Labeled=510 | Acc=0.8333 | F1=0.8343 | G-Mean=0.8292 | MCC=0.8239
#
# === Active Learning: SVM | Random Oversampling ===
#   [SVM] Iter  1 | Labeled=501 | Acc=0.2421 | F1=0.1763 | G-Mean=0.3056 | MCC=0.2073
#   [SVM] Iter  2 | Labeled=502 | Acc=0.2469 | F1=0.1808 | G-Mean=0.3130 | MCC=0.2126
#   [SVM] Iter  3 | Labeled=503 | Acc=0.2469 | F1=0.1817 | G-Mean=0.3197 | MCC=0.2114
#   [SVM] Iter  4 | Labeled=504 | Acc=0.2462 | F1=0.1804 | G-Mean=0.3177 | MCC=0.2104
#   [SVM] Iter  5 | Labeled=505 | Acc=0.2469 | F1=0.1807 | G-Mean=0.3183 | MCC=0.2112
#   [SVM] Iter  6 | Labeled=506 | Acc=0.2455 | F1=0.1794 | G-Mean=0.3157 | MCC=0.2098
#   [SVM] Iter  7 | Labeled=507 | Acc=0.2462 | F1=0.1742 | G-Mean=0.3756 | MCC=0.2110
#   [SVM] Iter  8 | Labeled=508 | Acc=0.2462 | F1=0.1742 | G-Mean=0.3756 | MCC=0.2110
#   [SVM] Iter  9 | Labeled=509 | Acc=0.2462 | F1=0.1742 | G-Mean=0.3756 | MCC=0.2110
#   [SVM] Iter 10 | Labeled=510 | Acc=0.2469 | F1=0.1746 | G-Mean=0.3764 | MCC=0.2117
#
# === Active Learning: Naive Bayes | Random Oversampling ===
#   [Naive Bayes] Iter  1 | Labeled=501 | Acc=0.7620 | F1=0.7433 | G-Mean=0.7109 | MCC=0.7507
#   [Naive Bayes] Iter  2 | Labeled=502 | Acc=0.7627 | F1=0.7442 | G-Mean=0.7120 | MCC=0.7514
#   [Naive Bayes] Iter  3 | Labeled=503 | Acc=0.7647 | F1=0.7464 | G-Mean=0.7143 | MCC=0.7535
#   [Naive Bayes] Iter  4 | Labeled=504 | Acc=0.7647 | F1=0.7464 | G-Mean=0.7143 | MCC=0.7535
#   [Naive Bayes] Iter  5 | Labeled=505 | Acc=0.7647 | F1=0.7464 | G-Mean=0.7144 | MCC=0.7535
#   [Naive Bayes] Iter  6 | Labeled=506 | Acc=0.7661 | F1=0.7476 | G-Mean=0.7155 | MCC=0.7549
#   [Naive Bayes] Iter  7 | Labeled=507 | Acc=0.7695 | F1=0.7521 | G-Mean=0.7223 | MCC=0.7585
#   [Naive Bayes] Iter  8 | Labeled=508 | Acc=0.7695 | F1=0.7521 | G-Mean=0.7223 | MCC=0.7585
#   [Naive Bayes] Iter  9 | Labeled=509 | Acc=0.7689 | F1=0.7515 | G-Mean=0.7216 | MCC=0.7578
#   [Naive Bayes] Iter 10 | Labeled=510 | Acc=0.7689 | F1=0.7515 | G-Mean=0.7216 | MCC=0.7578
#
# === Active Learning: K-Nearest Neighbors | Random Oversampling ===
#   [K-Nearest Neighbors] Iter  1 | Labeled=501 | Acc=0.2469 | F1=0.2291 | G-Mean=0.1825 | MCC=0.2041
#   [K-Nearest Neighbors] Iter  2 | Labeled=502 | Acc=0.2462 | F1=0.2279 | G-Mean=0.1796 | MCC=0.2034
#   [K-Nearest Neighbors] Iter  3 | Labeled=503 | Acc=0.2476 | F1=0.2290 | G-Mean=0.1803 | MCC=0.2049
#   [K-Nearest Neighbors] Iter  4 | Labeled=504 | Acc=0.2476 | F1=0.2289 | G-Mean=0.1803 | MCC=0.2049
#   [K-Nearest Neighbors] Iter  5 | Labeled=505 | Acc=0.2503 | F1=0.2301 | G-Mean=0.1776 | MCC=0.2079
#   [K-Nearest Neighbors] Iter  6 | Labeled=506 | Acc=0.2524 | F1=0.2315 | G-Mean=0.1775 | MCC=0.2102
#   [K-Nearest Neighbors] Iter  7 | Labeled=507 | Acc=0.2531 | F1=0.2320 | G-Mean=0.1779 | MCC=0.2109
#   [K-Nearest Neighbors] Iter  8 | Labeled=508 | Acc=0.2558 | F1=0.2341 | G-Mean=0.1788 | MCC=0.2138
#   [K-Nearest Neighbors] Iter  9 | Labeled=509 | Acc=0.2565 | F1=0.2349 | G-Mean=0.1829 | MCC=0.2145
#   [K-Nearest Neighbors] Iter 10 | Labeled=510 | Acc=0.2565 | F1=0.2350 | G-Mean=0.1829 | MCC=0.2146
#
# === Active Learning: Decision Tree | Random Oversampling ===
#   [Decision Tree] Iter  1 | Labeled=501 | Acc=0.7702 | F1=0.7708 | G-Mean=0.7554 | MCC=0.7574
#   [Decision Tree] Iter  2 | Labeled=502 | Acc=0.7709 | F1=0.7708 | G-Mean=0.7572 | MCC=0.7582
#   [Decision Tree] Iter  3 | Labeled=503 | Acc=0.7805 | F1=0.7807 | G-Mean=0.7691 | MCC=0.7685
#   [Decision Tree] Iter  4 | Labeled=504 | Acc=0.7750 | F1=0.7763 | G-Mean=0.7625 | MCC=0.7624
#   [Decision Tree] Iter  5 | Labeled=505 | Acc=0.7606 | F1=0.7617 | G-Mean=0.7499 | MCC=0.7472
#   [Decision Tree] Iter  6 | Labeled=506 | Acc=0.7606 | F1=0.7596 | G-Mean=0.7451 | MCC=0.7471
#   [Decision Tree] Iter  7 | Labeled=507 | Acc=0.7695 | F1=0.7694 | G-Mean=0.7568 | MCC=0.7566
#   [Decision Tree] Iter  8 | Labeled=508 | Acc=0.7757 | F1=0.7766 | G-Mean=0.7660 | MCC=0.7630
#   [Decision Tree] Iter  9 | Labeled=509 | Acc=0.7586 | F1=0.7588 | G-Mean=0.7437 | MCC=0.7450
#   [Decision Tree] Iter 10 | Labeled=510 | Acc=0.7675 | F1=0.7664 | G-Mean=0.7546 | MCC=0.7544
#
# === Active Learning: Random Forest | Random Oversampling ===
#   [Random Forest] Iter  1 | Labeled=501 | Acc=0.8717 | F1=0.8710 | G-Mean=0.8684 | MCC=0.8645
#   [Random Forest] Iter  2 | Labeled=502 | Acc=0.8786 | F1=0.8782 | G-Mean=0.8765 | MCC=0.8717
#   [Random Forest] Iter  3 | Labeled=503 | Acc=0.8704 | F1=0.8697 | G-Mean=0.8671 | MCC=0.8631
#   [Random Forest] Iter  4 | Labeled=504 | Acc=0.8813 | F1=0.8807 | G-Mean=0.8787 | MCC=0.8746
#   [Random Forest] Iter  5 | Labeled=505 | Acc=0.8820 | F1=0.8814 | G-Mean=0.8795 | MCC=0.8753
#   [Random Forest] Iter  6 | Labeled=506 | Acc=0.8834 | F1=0.8825 | G-Mean=0.8803 | MCC=0.8768
#   [Random Forest] Iter  7 | Labeled=507 | Acc=0.8779 | F1=0.8772 | G-Mean=0.8750 | MCC=0.8710
#   [Random Forest] Iter  8 | Labeled=508 | Acc=0.8793 | F1=0.8790 | G-Mean=0.8767 | MCC=0.8724
#   [Random Forest] Iter  9 | Labeled=509 | Acc=0.8779 | F1=0.8776 | G-Mean=0.8755 | MCC=0.8709
#   [Random Forest] Iter 10 | Labeled=510 | Acc=0.8731 | F1=0.8728 | G-Mean=0.8705 | MCC=0.8659
#
# === Active Learning: Gradient Boosting | Random Oversampling ===
#   [Gradient Boosting] Iter  1 | Labeled=501 | Acc=0.8663 | F1=0.8647 | G-Mean=0.8619 | MCC=0.8587
#   [Gradient Boosting] Iter  2 | Labeled=502 | Acc=0.8642 | F1=0.8627 | G-Mean=0.8600 | MCC=0.8565
# ...
#   [Decision Tree] Iter  8 | Labeled=508 | Acc=0.7785 | F1=0.7797 | G-Mean=0.7716 | MCC=0.7657
#   [Decision Tree] Iter  9 | Labeled=509 | Acc=0.7901 | F1=0.7908 | G-Mean=0.7832 | MCC=0.7783
#   [Decision Tree] Iter 10 | Labeled=510 | Acc=0.7840 | F1=0.7850 | G-Mean=0.7780 | MCC=0.7718
#
# === Active Learning: Random Forest | SMOTE ===
#   [Random Forest] Iter  1 | Labeled=501 | Acc=0.8711 | F1=0.8696 | G-Mean=0.8665 | MCC=0.8637
#   [Random Forest] Iter  2 | Labeled=502 | Acc=0.8786 | F1=0.8772 | G-Mean=0.8747 | MCC=0.8717
#   [Random Forest] Iter  3 | Labeled=503 | Acc=0.8752 | F1=0.8736 | G-Mean=0.8709 | MCC=0.8680
#   [Random Forest] Iter  4 | Labeled=504 | Acc=0.8745 | F1=0.8733 | G-Mean=0.8708 | MCC=0.8673
#   [Random Forest] Iter  5 | Labeled=505 | Acc=0.8759 | F1=0.8746 | G-Mean=0.8715 | MCC=0.8688
#   [Random Forest] Iter  6 | Labeled=506 | Acc=0.8745 | F1=0.8733 | G-Mean=0.8704 | MCC=0.8673
#   [Random Forest] Iter  7 | Labeled=507 | Acc=0.8697 | F1=0.8682 | G-Mean=0.8648 | MCC=0.8623
#   [Random Forest] Iter  8 | Labeled=508 | Acc=0.8752 | F1=0.8738 | G-Mean=0.8708 | MCC=0.8681
#   [Random Forest] Iter  9 | Labeled=509 | Acc=0.8704 | F1=0.8690 | G-Mean=0.8658 | MCC=0.8630
#   [Random Forest] Iter 10 | Labeled=510 | Acc=0.8663 | F1=0.8649 | G-Mean=0.8618 | MCC=0.8586
#
# === Active Learning: Gradient Boosting | SMOTE ===
#   [Gradient Boosting] Iter  1 | Labeled=501 | Acc=0.8148 | F1=0.8114 | G-Mean=0.8034 | MCC=0.8044
#   [Gradient Boosting] Iter  2 | Labeled=502 | Acc=0.8128 | F1=0.8100 | G-Mean=0.8027 | MCC=0.8021
#   [Gradient Boosting] Iter  3 | Labeled=503 | Acc=0.8176 | F1=0.8147 | G-Mean=0.8074 | MCC=0.8072
#   [Gradient Boosting] Iter  4 | Labeled=504 | Acc=0.8100 | F1=0.8066 | G-Mean=0.7987 | MCC=0.7992
#   [Gradient Boosting] Iter  5 | Labeled=505 | Acc=0.8121 | F1=0.8088 | G-Mean=0.8006 | MCC=0.8014
#   [Gradient Boosting] Iter  6 | Labeled=506 | Acc=0.8107 | F1=0.8078 | G-Mean=0.7996 | MCC=0.7999
#   [Gradient Boosting] Iter  7 | Labeled=507 | Acc=0.8189 | F1=0.8161 | G-Mean=0.8090 | MCC=0.8086
#   [Gradient Boosting] Iter  8 | Labeled=508 | Acc=0.8182 | F1=0.8156 | G-Mean=0.8092 | MCC=0.8079
#   [Gradient Boosting] Iter  9 | Labeled=509 | Acc=0.8196 | F1=0.8168 | G-Mean=0.8098 | MCC=0.8093
#   [Gradient Boosting] Iter 10 | Labeled=510 | Acc=0.8244 | F1=0.8215 | G-Mean=0.8147 | MCC=0.8144
#
# === Active Learning: XGBoost | SMOTE ===
#   [XGBoost] Iter  1 | Labeled=501 | Acc=0.8340 | F1=0.8331 | G-Mean=0.8282 | MCC=0.8245
#   [XGBoost] Iter  2 | Labeled=502 | Acc=0.8388 | F1=0.8378 | G-Mean=0.8336 | MCC=0.8296
#   [XGBoost] Iter  3 | Labeled=503 | Acc=0.8388 | F1=0.8379 | G-Mean=0.8332 | MCC=0.8296
#   [XGBoost] Iter  4 | Labeled=504 | Acc=0.8443 | F1=0.8435 | G-Mean=0.8392 | MCC=0.8354
#   [XGBoost] Iter  5 | Labeled=505 | Acc=0.8402 | F1=0.8392 | G-Mean=0.8347 | MCC=0.8310
#   [XGBoost] Iter  6 | Labeled=506 | Acc=0.8368 | F1=0.8362 | G-Mean=0.8315 | MCC=0.8274
#   [XGBoost] Iter  7 | Labeled=507 | Acc=0.8416 | F1=0.8408 | G-Mean=0.8359 | MCC=0.8325
#   [XGBoost] Iter  8 | Labeled=508 | Acc=0.8402 | F1=0.8390 | G-Mean=0.8342 | MCC=0.8310
#   [XGBoost] Iter  9 | Labeled=509 | Acc=0.8395 | F1=0.8383 | G-Mean=0.8339 | MCC=0.8303
#   [XGBoost] Iter 10 | Labeled=510 | Acc=0.8409 | F1=0.8398 | G-Mean=0.8355 | MCC=0.8318
#
# === Active Learning: LightGBM | SMOTE ===
#   [LightGBM] Iter  1 | Labeled=501 | Acc=0.8402 | F1=0.8394 | G-Mean=0.8338 | MCC=0.8311
#   [LightGBM] Iter  2 | Labeled=502 | Acc=0.8388 | F1=0.8379 | G-Mean=0.8327 | MCC=0.8296
#   [LightGBM] Iter  3 | Labeled=503 | Acc=0.8381 | F1=0.8373 | G-Mean=0.8317 | MCC=0.8289
#   [LightGBM] Iter  4 | Labeled=504 | Acc=0.8436 | F1=0.8424 | G-Mean=0.8367 | MCC=0.8347
#   [LightGBM] Iter  5 | Labeled=505 | Acc=0.8457 | F1=0.8447 | G-Mean=0.8383 | MCC=0.8369
#   [LightGBM] Iter  6 | Labeled=506 | Acc=0.8477 | F1=0.8466 | G-Mean=0.8408 | MCC=0.8391
#   [LightGBM] Iter  7 | Labeled=507 | Acc=0.8464 | F1=0.8454 | G-Mean=0.8401 | MCC=0.8376
#   [LightGBM] Iter  8 | Labeled=508 | Acc=0.8464 | F1=0.8453 | G-Mean=0.8406 | MCC=0.8376
#   [LightGBM] Iter  9 | Labeled=509 | Acc=0.8505 | F1=0.8490 | G-Mean=0.8440 | MCC=0.8419
#   [LightGBM] Iter 10 | Labeled=510 | Acc=0.8512 | F1=0.8499 | G-Mean=0.8446 | MCC=0.8427
#
# === Active Learning: CatBoost | SMOTE ===
#   [CatBoost] Iter  1 | Labeled=501 | Acc=0.8594 | F1=0.8587 | G-Mean=0.8559 | MCC=0.8512
#   [CatBoost] Iter  2 | Labeled=502 | Acc=0.8628 | F1=0.8623 | G-Mean=0.8594 | MCC=0.8549
#   [CatBoost] Iter  3 | Labeled=503 | Acc=0.8628 | F1=0.8620 | G-Mean=0.8592 | MCC=0.8549
#   [CatBoost] Iter  4 | Labeled=504 | Acc=0.8642 | F1=0.8636 | G-Mean=0.8610 | MCC=0.8563
#   [CatBoost] Iter  5 | Labeled=505 | Acc=0.8628 | F1=0.8622 | G-Mean=0.8596 | MCC=0.8548
#   [CatBoost] Iter  6 | Labeled=506 | Acc=0.8649 | F1=0.8643 | G-Mean=0.8618 | MCC=0.8570
#   [CatBoost] Iter  7 | Labeled=507 | Acc=0.8628 | F1=0.8622 | G-Mean=0.8596 | MCC=0.8549
#   [CatBoost] Iter  8 | Labeled=508 | Acc=0.8628 | F1=0.8622 | G-Mean=0.8596 | MCC=0.8549
#   [CatBoost] Iter  9 | Labeled=509 | Acc=0.8663 | F1=0.8656 | G-Mean=0.8629 | MCC=0.8585
#   [CatBoost] Iter 10 | Labeled=510 | Acc=0.8724 | F1=0.8717 | G-Mean=0.8692 | MCC=0.8650
#
# === Active Learning: AdaBoost | SMOTE ===
#   [AdaBoost] Iter  1 | Labeled=501 | Acc=0.2483 | F1=0.1408 | G-Mean=0.3676 | MCC=0.2202
#   [AdaBoost] Iter  2 | Labeled=502 | Acc=0.2695 | F1=0.1833 | G-Mean=0.4917 | MCC=0.2342
#   [AdaBoost] Iter  3 | Labeled=503 | Acc=0.2483 | F1=0.1381 | G-Mean=0.4194 | MCC=0.2270
#   [AdaBoost] Iter  4 | Labeled=504 | Acc=0.2435 | F1=0.1495 | G-Mean=0.3627 | MCC=0.2182
#   [AdaBoost] Iter  5 | Labeled=505 | Acc=0.2160 | F1=0.1170 | G-Mean=0.2143 | MCC=0.1871
#   [AdaBoost] Iter  6 | Labeled=506 | Acc=0.2599 | F1=0.1587 | G-Mean=0.2257 | MCC=0.2320
#   [AdaBoost] Iter  7 | Labeled=507 | Acc=0.2394 | F1=0.1180 | G-Mean=0.3058 | MCC=0.2169
#   [AdaBoost] Iter  8 | Labeled=508 | Acc=0.1914 | F1=0.1027 | G-Mean=0.1639 | MCC=0.1588
#   [AdaBoost] Iter  9 | Labeled=509 | Acc=0.2160 | F1=0.1180 | G-Mean=0.2379 | MCC=0.1822
#   [AdaBoost] Iter 10 | Labeled=510 | Acc=0.2593 | F1=0.1467 | G-Mean=0.4216 | MCC=0.2346
#
# === Active Learning: Extra Trees | SMOTE ===
#   [Extra Trees] Iter  1 | Labeled=501 | Acc=0.8532 | F1=0.8521 | G-Mean=0.8486 | MCC=0.8449
#   [Extra Trees] Iter  2 | Labeled=502 | Acc=0.8443 | F1=0.8434 | G-Mean=0.8397 | MCC=0.8354
#   [Extra Trees] Iter  3 | Labeled=503 | Acc=0.8464 | F1=0.8449 | G-Mean=0.8409 | MCC=0.8376
#   [Extra Trees] Iter  4 | Labeled=504 | Acc=0.8409 | F1=0.8396 | G-Mean=0.8354 | MCC=0.8318
#   [Extra Trees] Iter  5 | Labeled=505 | Acc=0.8450 | F1=0.8436 | G-Mean=0.8395 | MCC=0.8362
#   [Extra Trees] Iter  6 | Labeled=506 | Acc=0.8512 | F1=0.8497 | G-Mean=0.8462 | MCC=0.8427
#   [Extra Trees] Iter  7 | Labeled=507 | Acc=0.8491 | F1=0.8481 | G-Mean=0.8445 | MCC=0.8405
#   [Extra Trees] Iter  8 | Labeled=508 | Acc=0.8498 | F1=0.8488 | G-Mean=0.8448 | MCC=0.8413
#   [Extra Trees] Iter  9 | Labeled=509 | Acc=0.8429 | F1=0.8416 | G-Mean=0.8374 | MCC=0.8341
#   [Extra Trees] Iter 10 | Labeled=510 | Acc=0.8450 | F1=0.8442 | G-Mean=0.8406 | MCC=0.8362
#
# === Active Learning: Ridge Classifier | SMOTE ===
#   [Ridge Classifier] Iter  1 | Labeled=501 | Acc=0.6571 | F1=0.6332 | G-Mean=0.5908 | MCC=0.6423
#   [Ridge Classifier] Iter  2 | Labeled=502 | Acc=0.6557 | F1=0.6315 | G-Mean=0.5883 | MCC=0.6410
#   [Ridge Classifier] Iter  3 | Labeled=503 | Acc=0.6591 | F1=0.6338 | G-Mean=0.5901 | MCC=0.6445
#   [Ridge Classifier] Iter  4 | Labeled=504 | Acc=0.6584 | F1=0.6323 | G-Mean=0.5880 | MCC=0.6438
#   [Ridge Classifier] Iter  5 | Labeled=505 | Acc=0.6591 | F1=0.6333 | G-Mean=0.5893 | MCC=0.6446
#   [Ridge Classifier] Iter  6 | Labeled=506 | Acc=0.6543 | F1=0.6276 | G-Mean=0.5818 | MCC=0.6398
#   [Ridge Classifier] Iter  7 | Labeled=507 | Acc=0.6578 | F1=0.6326 | G-Mean=0.5882 | MCC=0.6435
#   [Ridge Classifier] Iter  8 | Labeled=508 | Acc=0.6557 | F1=0.6303 | G-Mean=0.5856 | MCC=0.6414
#   [Ridge Classifier] Iter  9 | Labeled=509 | Acc=0.6550 | F1=0.6292 | G-Mean=0.5836 | MCC=0.6407
#   [Ridge Classifier] Iter 10 | Labeled=510 | Acc=0.6578 | F1=0.6306 | G-Mean=0.5838 | MCC=0.6435
#
# === Active Learning: Perceptron | SMOTE ===
#   [Perceptron] Iter  1 | Labeled=501 | Acc=0.1914 | F1=0.1341 | G-Mean=0.2735 | MCC=0.1520
#   [Perceptron] Iter  2 | Labeled=502 | Acc=0.1523 | F1=0.0874 | G-Mean=0.1603 | MCC=0.1135
#   [Perceptron] Iter  3 | Labeled=503 | Acc=0.1811 | F1=0.1091 | G-Mean=0.4008 | MCC=0.1456
#   [Perceptron] Iter  4 | Labeled=504 | Acc=0.1433 | F1=0.0868 | G-Mean=0.2326 | MCC=0.1133
#   [Perceptron] Iter  5 | Labeled=505 | Acc=0.1454 | F1=0.0910 | G-Mean=0.2381 | MCC=0.1042
#   [Perceptron] Iter  6 | Labeled=506 | Acc=0.1269 | F1=0.0620 | G-Mean=0.1218 | MCC=0.0873
#   [Perceptron] Iter  7 | Labeled=507 | Acc=0.1646 | F1=0.1045 | G-Mean=0.2088 | MCC=0.1240
#   [Perceptron] Iter  8 | Labeled=508 | Acc=0.1365 | F1=0.0786 | G-Mean=0.1510 | MCC=0.0936
#   [Perceptron] Iter  9 | Labeled=509 | Acc=0.1804 | F1=0.1258 | G-Mean=0.2019 | MCC=0.1502
#   [Perceptron] Iter 10 | Labeled=510 | Acc=0.1728 | F1=0.0869 | G-Mean=0.2514 | MCC=0.1404
#
# === Active Learning: Bagging Classifier | SMOTE ===
#   [Bagging Classifier] Iter  1 | Labeled=501 | Acc=0.8237 | F1=0.8230 | G-Mean=0.8191 | MCC=0.8135
#   [Bagging Classifier] Iter  2 | Labeled=502 | Acc=0.8320 | F1=0.8312 | G-Mean=0.8274 | MCC=0.8223
#   [Bagging Classifier] Iter  3 | Labeled=503 | Acc=0.8278 | F1=0.8271 | G-Mean=0.8233 | MCC=0.8179
#   [Bagging Classifier] Iter  4 | Labeled=504 | Acc=0.8299 | F1=0.8291 | G-Mean=0.8252 | MCC=0.8201
#   [Bagging Classifier] Iter  5 | Labeled=505 | Acc=0.8361 | F1=0.8353 | G-Mean=0.8315 | MCC=0.8266
#   [Bagging Classifier] Iter  6 | Labeled=506 | Acc=0.8368 | F1=0.8353 | G-Mean=0.8313 | MCC=0.8274
#   [Bagging Classifier] Iter  7 | Labeled=507 | Acc=0.8361 | F1=0.8345 | G-Mean=0.8305 | MCC=0.8267
#   [Bagging Classifier] Iter  8 | Labeled=508 | Acc=0.8340 | F1=0.8326 | G-Mean=0.8286 | MCC=0.8245
#   [Bagging Classifier] Iter  9 | Labeled=509 | Acc=0.8402 | F1=0.8389 | G-Mean=0.8354 | MCC=0.8310
#   [Bagging Classifier] Iter 10 | Labeled=510 | Acc=0.8361 | F1=0.8347 | G-Mean=0.8311 | MCC=0.8267
#
# === Active Learning: GaussianNB | SMOTE ===
#   [GaussianNB] Iter  1 | Labeled=501 | Acc=0.7401 | F1=0.7144 | G-Mean=0.6661 | MCC=0.7285
#   [GaussianNB] Iter  2 | Labeled=502 | Acc=0.7414 | F1=0.7162 | G-Mean=0.6684 | MCC=0.7299
#   [GaussianNB] Iter  3 | Labeled=503 | Acc=0.7421 | F1=0.7151 | G-Mean=0.6641 | MCC=0.7309
#   [GaussianNB] Iter  4 | Labeled=504 | Acc=0.7421 | F1=0.7155 | G-Mean=0.6661 | MCC=0.7309
#   [GaussianNB] Iter  5 | Labeled=505 | Acc=0.7428 | F1=0.7158 | G-Mean=0.6661 | MCC=0.7317
#   [GaussianNB] Iter  6 | Labeled=506 | Acc=0.7414 | F1=0.7143 | G-Mean=0.6645 | MCC=0.7302
#   [GaussianNB] Iter  7 | Labeled=507 | Acc=0.7394 | F1=0.7121 | G-Mean=0.6624 | MCC=0.7280
#   [GaussianNB] Iter  8 | Labeled=508 | Acc=0.7407 | F1=0.7136 | G-Mean=0.6634 | MCC=0.7296
#   [GaussianNB] Iter  9 | Labeled=509 | Acc=0.7401 | F1=0.7131 | G-Mean=0.6631 | MCC=0.7288
#   [GaussianNB] Iter 10 | Labeled=510 | Acc=0.7407 | F1=0.7136 | G-Mean=0.6636 | MCC=0.7295
#
# === Active Learning: Stacking | SMOTE ===
#   [Stacking] Iter  1 | Labeled=501 | Acc=0.8615 | F1=0.8613 | G-Mean=0.8576 | MCC=0.8535
#   [Stacking] Iter  2 | Labeled=502 | Acc=0.8621 | F1=0.8623 | G-Mean=0.8581 | MCC=0.8542
#   [Stacking] Iter  3 | Labeled=503 | Acc=0.8594 | F1=0.8595 | G-Mean=0.8553 | MCC=0.8513
#   [Stacking] Iter  4 | Labeled=504 | Acc=0.8608 | F1=0.8607 | G-Mean=0.8567 | MCC=0.8527
#   [Stacking] Iter  5 | Labeled=505 | Acc=0.8601 | F1=0.8600 | G-Mean=0.8564 | MCC=0.8520
#   [Stacking] Iter  6 | Labeled=506 | Acc=0.8649 | F1=0.8645 | G-Mean=0.8605 | MCC=0.8571
#   [Stacking] Iter  7 | Labeled=507 | Acc=0.8656 | F1=0.8653 | G-Mean=0.8613 | MCC=0.8578
#   [Stacking] Iter  8 | Labeled=508 | Acc=0.8663 | F1=0.8659 | G-Mean=0.8619 | MCC=0.8586
#   [Stacking] Iter  9 | Labeled=509 | Acc=0.8663 | F1=0.8659 | G-Mean=0.8617 | MCC=0.8586
#   [Stacking] Iter 10 | Labeled=510 | Acc=0.8628 | F1=0.8628 | G-Mean=0.8590 | MCC=0.8549
#
# === Active Learning: Hard Voting | SMOTE ===
#   [Hard Voting] Iter  1 | Labeled=501 | Acc=0.8621 | F1=0.8607 | G-Mean=0.8565 | MCC=0.8543
#   [Hard Voting] Iter  2 | Labeled=502 | Acc=0.8573 | F1=0.8559 | G-Mean=0.8513 | MCC=0.8492
#   [Hard Voting] Iter  3 | Labeled=503 | Acc=0.8573 | F1=0.8561 | G-Mean=0.8518 | MCC=0.8492
#   [Hard Voting] Iter  4 | Labeled=504 | Acc=0.8587 | F1=0.8572 | G-Mean=0.8528 | MCC=0.8506
#   [Hard Voting] Iter  5 | Labeled=505 | Acc=0.8615 | F1=0.8599 | G-Mean=0.8555 | MCC=0.8536
#   [Hard Voting] Iter  6 | Labeled=506 | Acc=0.8594 | F1=0.8579 | G-Mean=0.8535 | MCC=0.8514
#   [Hard Voting] Iter  7 | Labeled=507 | Acc=0.8601 | F1=0.8587 | G-Mean=0.8546 | MCC=0.8521
#   [Hard Voting] Iter  8 | Labeled=508 | Acc=0.8594 | F1=0.8579 | G-Mean=0.8535 | MCC=0.8514
#   [Hard Voting] Iter  9 | Labeled=509 | Acc=0.8608 | F1=0.8594 | G-Mean=0.8551 | MCC=0.8529
#   [Hard Voting] Iter 10 | Labeled=510 | Acc=0.8608 | F1=0.8592 | G-Mean=0.8547 | MCC=0.8529
#
# === Active Learning: Soft Voting | SMOTE ===
#   [Soft Voting] Iter  1 | Labeled=501 | Acc=0.8539 | F1=0.8529 | G-Mean=0.8485 | MCC=0.8456
#   [Soft Voting] Iter  2 | Labeled=502 | Acc=0.8560 | F1=0.8548 | G-Mean=0.8503 | MCC=0.8477
#   [Soft Voting] Iter  3 | Labeled=503 | Acc=0.8546 | F1=0.8531 | G-Mean=0.8482 | MCC=0.8463
#   [Soft Voting] Iter  4 | Labeled=504 | Acc=0.8580 | F1=0.8568 | G-Mean=0.8522 | MCC=0.8499
#   [Soft Voting] Iter  5 | Labeled=505 | Acc=0.8567 | F1=0.8552 | G-Mean=0.8504 | MCC=0.8485
#   [Soft Voting] Iter  6 | Labeled=506 | Acc=0.8594 | F1=0.8581 | G-Mean=0.8535 | MCC=0.8514
#   [Soft Voting] Iter  7 | Labeled=507 | Acc=0.8594 | F1=0.8582 | G-Mean=0.8533 | MCC=0.8514
#   [Soft Voting] Iter  8 | Labeled=508 | Acc=0.8580 | F1=0.8567 | G-Mean=0.8520 | MCC=0.8499
#   [Soft Voting] Iter  9 | Labeled=509 | Acc=0.8587 | F1=0.8572 | G-Mean=0.8521 | MCC=0.8507
#   [Soft Voting] Iter 10 | Labeled=510 | Acc=0.8573 | F1=0.8561 | G-Mean=0.8511 | MCC=0.8492
#
# === Active Learning: Weighted Voting | SMOTE ===
#   [Weighted Voting] Iter  1 | Labeled=501 | Acc=0.8567 | F1=0.8554 | G-Mean=0.8509 | MCC=0.8485
#   [Weighted Voting] Iter  2 | Labeled=502 | Acc=0.8594 | F1=0.8581 | G-Mean=0.8538 | MCC=0.8514
#   [Weighted Voting] Iter  3 | Labeled=503 | Acc=0.8573 | F1=0.8561 | G-Mean=0.8516 | MCC=0.8492
#   [Weighted Voting] Iter  4 | Labeled=504 | Acc=0.8587 | F1=0.8573 | G-Mean=0.8529 | MCC=0.8507
#   [Weighted Voting] Iter  5 | Labeled=505 | Acc=0.8567 | F1=0.8553 | G-Mean=0.8507 | MCC=0.8485
#   [Weighted Voting] Iter  6 | Labeled=506 | Acc=0.8539 | F1=0.8526 | G-Mean=0.8481 | MCC=0.8456
#   [Weighted Voting] Iter  7 | Labeled=507 | Acc=0.8553 | F1=0.8538 | G-Mean=0.8488 | MCC=0.8470
#   [Weighted Voting] Iter  8 | Labeled=508 | Acc=0.8594 | F1=0.8578 | G-Mean=0.8529 | MCC=0.8514
#   [Weighted Voting] Iter  9 | Labeled=509 | Acc=0.8580 | F1=0.8567 | G-Mean=0.8517 | MCC=0.8499
#   [Weighted Voting] Iter 10 | Labeled=510 | Acc=0.8628 | F1=0.8614 | G-Mean=0.8569 | MCC=0.8550
#
# === Active Learning: Adding (Avg Probabilities) | SMOTE ===
#   [Adding (Avg Probabilities)] Iter  1 | Labeled=501 | Acc=0.8546 | F1=0.8536 | G-Mean=0.8493 | MCC=0.8463
#   [Adding (Avg Probabilities)] Iter  2 | Labeled=502 | Acc=0.8560 | F1=0.8548 | G-Mean=0.8503 | MCC=0.8477
#   [Adding (Avg Probabilities)] Iter  3 | Labeled=503 | Acc=0.8546 | F1=0.8531 | G-Mean=0.8482 | MCC=0.8463
#   [Adding (Avg Probabilities)] Iter  4 | Labeled=504 | Acc=0.8580 | F1=0.8568 | G-Mean=0.8522 | MCC=0.8499
#   [Adding (Avg Probabilities)] Iter  5 | Labeled=505 | Acc=0.8567 | F1=0.8552 | G-Mean=0.8504 | MCC=0.8485
#   [Adding (Avg Probabilities)] Iter  6 | Labeled=506 | Acc=0.8587 | F1=0.8574 | G-Mean=0.8528 | MCC=0.8507
#   [Adding (Avg Probabilities)] Iter  7 | Labeled=507 | Acc=0.8594 | F1=0.8582 | G-Mean=0.8533 | MCC=0.8514
#   [Adding (Avg Probabilities)] Iter  8 | Labeled=508 | Acc=0.8587 | F1=0.8573 | G-Mean=0.8526 | MCC=0.8506
#   [Adding (Avg Probabilities)] Iter  9 | Labeled=509 | Acc=0.8580 | F1=0.8566 | G-Mean=0.8514 | MCC=0.8499
#   [Adding (Avg Probabilities)] Iter 10 | Labeled=510 | Acc=0.8567 | F1=0.8555 | G-Mean=0.8504 | MCC=0.8485
